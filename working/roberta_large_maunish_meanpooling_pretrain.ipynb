# %% [markdown]
# <a href="https://colab.research.google.com/github/cpptake/CommonLit/blob/main/roberta_large_maunish_meanpooling_pretrain.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Result
#
# Performance estimates:
# [0.49805953176645995, 0.4736856332245972, 0.47809673197663416, 0.661411315004553, 0.5020951587008314]
# Mean: 0.522669674134615

# %% [markdown]
# # Prerequisite

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Select the Runtime > "Change runtime type" menu to enable a GPU accelerator, ')
  print('and then re-execute this cell.')
else:
  print(gpu_info)
# Out:
# Tue Jul 20 13:56:37 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 470.42.01    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   68C    P0    50W / 250W |  13733MiB / 16280MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %% [markdown]
# ## Install same version of library as Kaggle Notebook

# %%
# # cp でrequirementsをカレントdirにコピー
# !cp -f /content/drive/MyDrive/kaggle/commonlit/roberta-large/requirements.txt ./
# # !cat ./requirements.txt

# !mkdir /content/drive/MyDrive/CommonLit/input/commonlitreadabilityprize/roberta-large-mlm
# !unzip -n /content/drive/MyDrive/CommonLit/input/commonlitreadabilityprize/Roberta-large-mlm.zip -d /content/drive/MyDrive/CommonLit/input/commonlitreadabilityprize/roberta-large-mlm
# Out:
# Archive:  /content/drive/MyDrive/CommonLit/input/commonlitreadabilityprize/Roberta-large-mlm.zip
#   inflating: /content/drive/MyDrive/CommonLit/input/commonlitreadabilityprize/roberta-large-mlm/clrp_roberta_large/config.json
#   inflating: /content/drive/MyDrive/CommonLit/input/commonlitreadabilityprize/roberta-large-mlm/clrp_roberta_large/merges.txt
#   inflating: /content/drive/MyDrive/CommonLit/input/commonlitreadabilityprize/roberta-large-mlm/clrp_roberta_large/pytorch_model.bin
#   inflating: /content/drive/MyDrive/CommonLit/input/commonlitreadabilityprize/roberta-large-mlm/clrp_roberta_large/special_tokens_map.json
#   inflating: /content/drive/MyDrive/CommonLit/input/commonlitreadabilityprize/roberta-large-mlm/clrp_roberta_large/tokenizer_config.json
#   inflating: /content/drive/MyDrive/CommonLit/input/commonlitreadabilityprize/roberta-large-mlm/clrp_roberta_large/training_args.bin
#   inflating: /content/drive/MyDrive/CommonLit/input/commonlitreadabilityprize/roberta-large-mlm/clrp_roberta_large/vocab.json
#   inflating: /content/drive/MyDrive/CommonLit/input/commonlitreadabilityprize/roberta-large-mlm/clrp_roberta_large_chk/checkpoint-1200/config.json
#   inflating: /content/drive/MyDrive/CommonLit/input/commonlitreadabilityprize/roberta-large-mlm/clrp_roberta_large_chk/checkpoint-1200/optimizer.pt
#   inflating: /content/drive/MyDrive/CommonLit/input/commonlitreadabilityprize/roberta-large-mlm/clrp_roberta_large_chk/checkpoint-1200/pytorch_model.bin
#   inflating: /content/drive/MyDrive/CommonLit/input/commonlitreadabilityprize/roberta-large-mlm/clrp_roberta_large_chk/checkpoint-1200/scheduler.pt
#   inflating: /content/drive/MyDrive/CommonLit/input/commonlitreadabilityprize/roberta-large-mlm/clrp_roberta_large_chk/checkpoint-1200/trainer_state.json
#   inflating: /content/drive/MyDrive/CommonLit/input/commonlitreadabilityprize/roberta-large-mlm/clrp_roberta_large_chk/checkpoint-1200/training_args.bin
#   inflating: /content/drive/MyDrive/CommonLit/input/commonlitreadabilityprize/roberta-large-mlm/clrp_roberta_large_chk/checkpoint-1600/config.json
#   inflating: /content/drive/MyDrive/CommonLit/input/commonlitreadabilityprize/roberta-large-mlm/clrp_roberta_large_chk/checkpoint-1600/optimizer.pt
#   inflating: /content/drive/MyDrive/CommonLit/input/commonlitreadabilityprize/roberta-large-mlm/clrp_roberta_large_chk/checkpoint-1600/pytorch_model.bin
#   inflating: /content/drive/MyDrive/CommonLit/input/commonlitreadabilityprize/roberta-large-mlm/clrp_roberta_large_chk/checkpoint-1600/scheduler.pt
#   inflating: /content/drive/MyDrive/CommonLit/input/commonlitreadabilityprize/roberta-large-mlm/clrp_roberta_large_chk/checkpoint-1600/trainer_state.json
#   inflating: /content/drive/MyDrive/CommonLit/input/commonlitreadabilityprize/roberta-large-mlm/clrp_roberta_large_chk/checkpoint-1600/training_args.bin
#   inflating: /content/drive/MyDrive/CommonLit/input/commonlitreadabilityprize/roberta-large-mlm/text.txt

# %%
# !pip uninstall -r /content/drive/MyDrive/CommonLit/working/requirements.txt -y
# Out:
# Found existing installation: pandas 1.1.5
# Uninstalling pandas-1.1.5:
#   Successfully uninstalled pandas-1.1.5
# Found existing installation: sklearn 0.0
# Uninstalling sklearn-0.0:
#   Successfully uninstalled sklearn-0.0
# Found existing installation: sklearn-pandas 1.8.0
# Uninstalling sklearn-pandas-1.8.0:
#   Successfully uninstalled sklearn-pandas-1.8.0
# Found existing installation: torch 1.9.0+cu102
# Uninstalling torch-1.9.0+cu102:
#   Successfully uninstalled torch-1.9.0+cu102
# WARNING: Skipping torchmetrics as it is not installed.
# Found existing installation: torchvision 0.10.0+cu102
# Uninstalling torchvision-0.10.0+cu102:
#   Successfully uninstalled torchvision-0.10.0+cu102
# WARNING: Skipping transformers as it is not installed.

# %%
# !pip install -r /content/drive/MyDrive/CommonLit/working/requirements.txt
# Out:
# Collecting pandas==1.2.3
#   Downloading pandas-1.2.3-cp37-cp37m-manylinux1_x86_64.whl (9.9 MB)
#      |████████████████████████████████| 9.9 MB 5.1 MB/s
# Collecting sklearn==0.0
#   Downloading sklearn-0.0.tar.gz (1.1 kB)
# Collecting sklearn-pandas==2.1.0
#   Downloading sklearn_pandas-2.1.0-py2.py3-none-any.whl (10 kB)
# Collecting torch==1.7.0
#   Downloading torch-1.7.0-cp37-cp37m-manylinux1_x86_64.whl (776.7 MB)
#      |████████████████████████████████| 776.7 MB 3.7 kB/s
# Collecting torchmetrics==0.2.0
#   Downloading torchmetrics-0.2.0-py3-none-any.whl (176 kB)
#      |████████████████████████████████| 176 kB 85.3 MB/s
# Collecting torchvision==0.8.1
#   Downloading torchvision-0.8.1-cp37-cp37m-manylinux1_x86_64.whl (12.7 MB)
#      |████████████████████████████████| 12.7 MB 24.2 MB/s
# Collecting transformers==4.5.1
#   Downloading transformers-4.5.1-py3-none-any.whl (2.1 MB)
#      |████████████████████████████████| 2.1 MB 49.8 MB/s
# Requirement already satisfied: numpy>=1.16.5 in /usr/local/lib/python3.7/dist-packages (from pandas==1.2.3->-r /content/drive/MyDrive/CommonLit/working/requirements.txt (line 1)) (1.19.5)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas==1.2.3->-r /content/drive/MyDrive/CommonLit/working/requirements.txt (line 1)) (2018.9)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas==1.2.3->-r /content/drive/MyDrive/CommonLit/working/requirements.txt (line 1)) (2.8.1)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/dist-packages (from sklearn==0.0->-r /content/drive/MyDrive/CommonLit/working/requirements.txt (line 2)) (0.22.2.post1)
# Collecting scipy>=1.5.1
#   Downloading scipy-1.7.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.whl (28.5 MB)
#      |████████████████████████████████| 28.5 MB 1.3 MB/s
# Collecting scikit-learn
#   Downloading scikit_learn-0.24.2-cp37-cp37m-manylinux2010_x86_64.whl (22.3 MB)
#      |████████████████████████████████| 22.3 MB 1.2 MB/s
# Requirement already satisfied: future in /usr/local/lib/python3.7/dist-packages (from torch==1.7.0->-r /content/drive/MyDrive/CommonLit/working/requirements.txt (line 4)) (0.16.0)
# Collecting dataclasses
#   Downloading dataclasses-0.6-py3-none-any.whl (14 kB)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch==1.7.0->-r /content/drive/MyDrive/CommonLit/working/requirements.txt (line 4)) (3.7.4.3)
# Requirement already satisfied: pillow>=4.1.1 in /usr/local/lib/python3.7/dist-packages (from torchvision==0.8.1->-r /content/drive/MyDrive/CommonLit/working/requirements.txt (line 7)) (7.1.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers==4.5.1->-r /content/drive/MyDrive/CommonLit/working/requirements.txt (line 8)) (3.0.12)
# Collecting tokenizers<0.11,>=0.10.1
#   Downloading tokenizers-0.10.3-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (3.3 MB)
#      |████████████████████████████████| 3.3 MB 50.2 MB/s
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers==4.5.1->-r /content/drive/MyDrive/CommonLit/working/requirements.txt (line 8)) (2019.12.20)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from transformers==4.5.1->-r /content/drive/MyDrive/CommonLit/working/requirements.txt (line 8)) (21.0)
# Collecting sacremoses
#   Downloading sacremoses-0.0.45-py3-none-any.whl (895 kB)
#      |████████████████████████████████| 895 kB 53.0 MB/s
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers==4.5.1->-r /content/drive/MyDrive/CommonLit/working/requirements.txt (line 8)) (2.23.0)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from transformers==4.5.1->-r /content/drive/MyDrive/CommonLit/working/requirements.txt (line 8)) (4.6.1)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.7/dist-packages (from transformers==4.5.1->-r /content/drive/MyDrive/CommonLit/working/requirements.txt (line 8)) (4.41.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas==1.2.3->-r /content/drive/MyDrive/CommonLit/working/requirements.txt (line 1)) (1.15.0)
# Collecting threadpoolctl>=2.0.0
#   Downloading threadpoolctl-2.2.0-py3-none-any.whl (12 kB)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->sklearn==0.0->-r /content/drive/MyDrive/CommonLit/working/requirements.txt (line 2)) (1.0.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->transformers==4.5.1->-r /content/drive/MyDrive/CommonLit/working/requirements.txt (line 8)) (3.5.0)
# Requirement already satisfied: pyparsing>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->transformers==4.5.1->-r /content/drive/MyDrive/CommonLit/working/requirements.txt (line 8)) (2.4.7)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers==4.5.1->-r /content/drive/MyDrive/CommonLit/working/requirements.txt (line 8)) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers==4.5.1->-r /content/drive/MyDrive/CommonLit/working/requirements.txt (line 8)) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers==4.5.1->-r /content/drive/MyDrive/CommonLit/working/requirements.txt (line 8)) (2021.5.30)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers==4.5.1->-r /content/drive/MyDrive/CommonLit/working/requirements.txt (line 8)) (2.10)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers==4.5.1->-r /content/drive/MyDrive/CommonLit/working/requirements.txt (line 8)) (7.1.2)
# Building wheels for collected packages: sklearn
#   Building wheel for sklearn (setup.py) ... done
#   Created wheel for sklearn: filename=sklearn-0.0-py2.py3-none-any.whl size=1309 sha256=7f3e63065113564a673b90c45752ae65fce0f96c7a2106a3dcd665cf576996cc
#   Stored in directory: /root/.cache/pip/wheels/46/ef/c3/157e41f5ee1372d1be90b09f74f82b10e391eaacca8f22d33e
# Successfully built sklearn
# Installing collected packages: threadpoolctl, scipy, dataclasses, torch, tokenizers, scikit-learn, sacremoses, pandas, transformers, torchvision, torchmetrics, sklearn-pandas, sklearn
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.4.1
#     Uninstalling scipy-1.4.1:
#       Successfully uninstalled scipy-1.4.1
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 0.22.2.post1
#     Uninstalling scikit-learn-0.22.2.post1:
#       Successfully uninstalled scikit-learn-0.22.2.post1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchtext 0.10.0 requires torch==1.9.0, but you have torch 1.7.0 which is incompatible.
# google-colab 1.0.0 requires pandas~=1.1.0; python_version >= "3.0", but you have pandas 1.2.3 which is incompatible.
# albumentations 0.1.12 requires imgaug<0.2.7,>=0.2.5, but you have imgaug 0.2.9 which is incompatible.
# Successfully installed dataclasses-0.6 pandas-1.2.3 sacremoses-0.0.45 scikit-learn-0.24.2 scipy-1.7.0 sklearn-0.0 sklearn-pandas-2.1.0 threadpoolctl-2.2.0 tokenizers-0.10.3 torch-1.7.0 torchmetrics-0.2.0 torchvision-0.8.1 transformers-4.5.1

# %%
# !pip freeze |grep -e random -e math -e numpy -e pandas -e torch -e transformers -e sklearn -e gc
# Out:
# mpmath==1.2.1
# numpy==1.19.5
# pandas==1.2.3
# pandas-datareader==0.9.0
# pandas-gbq==0.13.3
# pandas-profiling==1.4.1
# sklearn==0.0
# sklearn-pandas==2.1.0
# tensorflow-gcs-config==2.5.0
# torch==1.7.0
# torchmetrics==0.2.0
# torchsummary==1.5.1
# torchtext==0.10.0
# torchvision==0.8.1
# transformers==4.5.1

# %% [markdown]
# ## Prepare dataset

# %% [markdown]
# ### kaggle.json

# %%
# !mkdir -p /root/.kaggle/
# !cp ./drive/MyDrive/kaggle/commonlit/kaggle.json ~/.kaggle/kaggle.json
# !chmod 600 ~/.kaggle/kaggle.json

# !pip install -q kaggle
# !mkdir /root/.kaggle
# !cp /content/drive/MyDrive/Colab\ Notebooks/kaggle.json /root/.kaggle/

# %% [markdown]
# ### Competition dataset

# %%
# !mkdir -p /content/drive/MyDrive/CommonLit/input/commonlitreadabilityprize/
# !kaggle competitions download -c commonlitreadabilityprize -p /content/drive/MyDrive/CommonLit/input/commonlitreadabilityprize/
# !cp -f ./drive/MyDrive/kaggle/commonlit/train_stratiKfold.csv.zip /content/drive/MyDrive/CommonLit/input/commonlitreadabilityprize/

# %%
# !unzip -o ../input/commonlitreadabilityprize/train.csv.zip -d ../input/commonlitreadabilityprize/
# !unzip -o ../input/commonlitreadabilityprize/train_stratiKfold.csv.zip -d ../input/commonlitreadabilityprize/

# %%
# !ls ../input/commonlitreadabilityprize/
# Out:
# ls: cannot access '../input/commonlitreadabilityprize/': No such file or directory

# %% [markdown]
# ### Pretrained RoBERTa Large
# - Pretrain RoBERTa Large in the same way as this notebook
#   - https://www.kaggle.com/maunish/clrp-pytorch-roberta-pretrain
# - Dataset:
#   - https://www.kaggle.com/iamnishipy/roberta-large-20210712191259-mlm

# %%
# !mkdir -p /content/drive/MyDrive/CommonLit/input/commonlitreadabilityprize/pretrained-model/
# !kaggle datasets download iamnishipy/roberta-large-20210712191259-mlm
# Out:
# 401 - Unauthorized

# %%
# !unzip -o ./roberta-large-20210712191259-mlm.zip -d ../input/commonlitreadabilityprize/pretrained-model/
# Out:
# unzip:  cannot find or open ./roberta-large-20210712191259-mlm.zip, ./roberta-large-20210712191259-mlm.zip.zip or ./roberta-large-20210712191259-mlm.zip.ZIP.

# %%
# !ls ../input/commonlitreadabilityprize/pretrained-model/
# Out:
# ls: cannot access '../input/commonlitreadabilityprize/pretrained-model/': No such file or directory

# %% [markdown]
# # Overview
# This is kernel is almost the same as [Lightweight Roberta solution in PyTorch](https://www.kaggle.com/andretugan/lightweight-roberta-solution-in-pytorch), but instead of "roberta-base", it starts from [Maunish's pre-trained model](https://www.kaggle.com/maunish/clrp-roberta-base).
#
# Acknowledgments: some ideas were taken from kernels by [Torch](https://www.kaggle.com/rhtsingh) and [Maunish](https://www.kaggle.com/maunish).

# %%
# !pip install transformers accelerate datasets
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.7/dist-packages (4.5.1)
# Collecting accelerate
#   Downloading accelerate-0.3.0-py3-none-any.whl (49 kB)
#      |████████████████████████████████| 49 kB 3.2 MB/s
# Collecting datasets
#   Downloading datasets-1.9.0-py3-none-any.whl (262 kB)
#      |████████████████████████████████| 262 kB 8.6 MB/s
# Requirement already satisfied: tokenizers<0.11,>=0.10.1 in /usr/local/lib/python3.7/dist-packages (from transformers) (0.10.3)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (1.19.5)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (2019.12.20)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers) (3.0.12)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.7/dist-packages (from transformers) (4.41.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from transformers) (21.0)
# Requirement already satisfied: sacremoses in /usr/local/lib/python3.7/dist-packages (from transformers) (0.0.45)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from transformers) (4.6.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers) (2.23.0)
# Collecting pyaml>=20.4.0
#   Downloading pyaml-20.4.0-py2.py3-none-any.whl (17 kB)
# Requirement already satisfied: torch>=1.4.0 in /usr/local/lib/python3.7/dist-packages (from accelerate) (1.7.0)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.7/dist-packages (from pyaml>=20.4.0->accelerate) (3.13)
# Requirement already satisfied: dataclasses in /usr/local/lib/python3.7/dist-packages (from torch>=1.4.0->accelerate) (0.6)
# Requirement already satisfied: future in /usr/local/lib/python3.7/dist-packages (from torch>=1.4.0->accelerate) (0.16.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch>=1.4.0->accelerate) (3.7.4.3)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from datasets) (1.2.3)
# Collecting fsspec>=2021.05.0
#   Downloading fsspec-2021.7.0-py3-none-any.whl (118 kB)
#      |████████████████████████████████| 118 kB 73.5 MB/s
# Requirement already satisfied: pyarrow!=4.0.0,>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from datasets) (3.0.0)
# Requirement already satisfied: dill in /usr/local/lib/python3.7/dist-packages (from datasets) (0.3.4)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.7/dist-packages (from datasets) (0.70.12.2)
# Collecting huggingface-hub<0.1.0
#   Downloading huggingface_hub-0.0.14-py3-none-any.whl (43 kB)
#      |████████████████████████████████| 43 kB 2.0 MB/s
# Collecting xxhash
#   Downloading xxhash-2.0.2-cp37-cp37m-manylinux2010_x86_64.whl (243 kB)
#      |████████████████████████████████| 243 kB 67.6 MB/s
# Requirement already satisfied: pyparsing>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->transformers) (2.4.7)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2021.5.30)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->transformers) (3.5.0)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->datasets) (2.8.1)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas->datasets) (2018.9)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas->datasets) (1.15.0)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (7.1.2)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (1.0.1)
# Installing collected packages: xxhash, pyaml, huggingface-hub, fsspec, datasets, accelerate
# Successfully installed accelerate-0.3.0 datasets-1.9.0 fsspec-2021.7.0 huggingface-hub-0.0.14 pyaml-20.4.0 xxhash-2.0.2

# %%
import os
import math
import random
import time

import numpy as np
import pandas as pd

import torch
import torch.nn as nn
from torch.utils.data import Dataset
from torch.utils.data import DataLoader

from transformers import AdamW
from transformers import AutoTokenizer
from transformers import AutoModel
from transformers import AutoConfig
from transformers import get_cosine_schedule_with_warmup

from sklearn.model_selection import KFold

import gc
gc.enable()

# %% [markdown]
# ## Prepare dataset

# %%
NUM_FOLDS = 5
NUM_EPOCHS = 3
BATCH_SIZE = 8
MAX_LEN = 248
EVAL_SCHEDULE = [(0.50, 16), (0.49, 8), (0.48, 4), (0.47, 2), (-1., 1)]

ROBERTA_PATH = "/content/drive/MyDrive/CommonLit/input/commonlitreadabilityprize/roberta-large-mlm/clrp_roberta_large"
TOKENIZER_PATH = "/content/drive/MyDrive/CommonLit/input/commonlitreadabilityprize/roberta-large-mlm/clrp_roberta_large"
# ROBERTA_PATH = "/content/drive/MyDrive/CommonLit/input/commonlitreadabilityprize/roberta-large"
# TOKENIZER_PATH = "/content/drive/MyDrive/CommonLit/input/commonlitreadabilityprize/roberta-large"

# ROBERTA_PATH = "../input/clrp-roberta-base/clrp_roberta_base"
# TOKENIZER_PATH = "../input/clrp-roberta-base/clrp_roberta_base"
DEVICE = "cuda" if torch.cuda.is_available() else "cpu"

# %%
def set_random_seed(random_seed):
    random.seed(random_seed)
    np.random.seed(random_seed)
    os.environ["PYTHONHASHSEED"] = str(random_seed)

    torch.manual_seed(random_seed)
    torch.cuda.manual_seed(random_seed)
    torch.cuda.manual_seed_all(random_seed)

    torch.backends.cudnn.deterministic = True

# %%
train_df = pd.read_csv("/content/drive/MyDrive/CommonLit/input/commonlitreadabilityprize/train.csv")

# Remove incomplete entries if any.
train_df.drop(train_df[(train_df.target == 0) & (train_df.standard_error == 0)].index,
              inplace=True)
train_df.reset_index(drop=True, inplace=True)

test_df = pd.read_csv("/content/drive/MyDrive/CommonLit/input/commonlitreadabilityprize/test.csv")
submission_df = pd.read_csv("/content/drive/MyDrive/CommonLit/input/commonlitreadabilityprize/sample_submission.csv")

# %%
tokenizer = AutoTokenizer.from_pretrained(TOKENIZER_PATH)

# %% [markdown]
# # Dataset

# %%
class LitDataset(Dataset):
    def __init__(self, df, inference_only=False):
        super().__init__()

        self.df = df        
        self.inference_only = inference_only
        self.text = df.excerpt.tolist()
        #self.text = [text.replace("\n", " ") for text in self.text]
        
        if not self.inference_only:
            self.target = torch.tensor(df.target.values, dtype=torch.float32)        
    
        self.encoded = tokenizer.batch_encode_plus(
            self.text,
            padding = 'max_length',            
            max_length = MAX_LEN,
            truncation = True,
            return_attention_mask=True
        )        
 

    def __len__(self):
        return len(self.df)

    
    def __getitem__(self, index):        
        input_ids = torch.tensor(self.encoded['input_ids'][index])
        attention_mask = torch.tensor(self.encoded['attention_mask'][index])
        
        if self.inference_only:
            return (input_ids, attention_mask)            
        else:
            target = self.target[index]
            return (input_ids, attention_mask, target)

# %% [markdown]
# # Model
# The model is inspired by the one from [Maunish](https://www.kaggle.com/maunish/clrp-roberta-svm).

# %%
class LitModel(nn.Module):
    def __init__(self):
        super().__init__()

        config = AutoConfig.from_pretrained(ROBERTA_PATH)
        config.update({"output_hidden_states":True, 
                       "hidden_dropout_prob": 0.0,
                       "layer_norm_eps": 1e-7})                       
        
        self.roberta = AutoModel.from_pretrained(ROBERTA_PATH, config=config)
        #https://towardsdatascience.com/attention-based-deep-multiple-instance-learning-1bb3df857e24
        # 768: node fully connected layer
        # 512: node attention layer
        # self.attention = nn.Sequential(            
        #     nn.Linear(768, 512),            
        #     nn.Tanh(),                       
        #     nn.Linear(512, 1),
        #     nn.Softmax(dim=1)
        # )        

        # self.regressor = nn.Sequential(                        
        #     nn.Linear(768, 1)                        
        # )


        #768 -> 1024
        #512 -> 768
        self.attention = nn.Sequential(            
            nn.Linear(1024, 768),            
            nn.Tanh(),                       
            nn.Linear(768, 1),
            nn.Softmax(dim=1)
        )        

        self.regressor = nn.Sequential(                        
            nn.Linear(1024, 1)                        
        )
        

    def forward(self, input_ids, attention_mask):
        # roberta_output = self.roberta(input_ids=input_ids,
        #                               attention_mask=attention_mask)
        
        roberta_output = self.roberta(input_ids=input_ids,
                                      attention_mask=attention_mask)
        
        last_hidden_state = roberta_output[0]
        input_mask_expanded = attention_mask.unsqueeze(-1).expand(last_hidden_state.size()).float()
        sum_embeddings = torch.sum(last_hidden_state * input_mask_expanded, 1)
        sum_mask = input_mask_expanded.sum(1)
        sum_mask = torch.clamp(sum_mask, min=1e-9)
        mean_embeddings = sum_embeddings / sum_mask

        # print(mean_embeddings.shape)

        logits = self.regressor(mean_embeddings)
        
        preds = logits.squeeze(-1).squeeze(-1)

        return preds

        #### nishipy original ####
        # # There are a total of 13 layers of hidden states.
        # # 1 for the embedding layer, and 12 for the 12 Roberta layers.
        # # We take the hidden states from the last Roberta layer.
        # last_layer_hidden_states = roberta_output.hidden_states[-1]

        # # The number of cells is MAX_LEN.
        # # The size of the hidden state of each cell is 768 (for roberta-base).
        # # In order to condense hidden states of all cells to a context vector,
        # # we compute a weighted average of the hidden states of all cells.
        # # We compute the weight of each cell, using the attention neural network.
        # weights = self.attention(last_layer_hidden_states)
                
        # # weights.shape is BATCH_SIZE x MAX_LEN x 1
        # # last_layer_hidden_states.shape is BATCH_SIZE x MAX_LEN x 768        
        # # Now we compute context_vector as the weighted average.
        # # context_vector.shape is BATCH_SIZE x 768
        # context_vector = torch.sum(weights * last_layer_hidden_states, dim=1)        
        
        # # Now we reduce the context vector to the prediction score.
        # return self.regressor(context_vector)

# %%
def eval_mse(model, data_loader):
    """Evaluates the mean squared error of the |model| on |data_loader|"""
    model.eval()            
    mse_sum = 0

    with torch.no_grad():
        for batch_num, (input_ids, attention_mask, target) in enumerate(data_loader):
            input_ids = input_ids.to(DEVICE)
            attention_mask = attention_mask.to(DEVICE)                        
            target = target.to(DEVICE)           
            
            pred = model(input_ids, attention_mask)                       

            mse_sum += nn.MSELoss(reduction="sum")(pred.flatten(), target).item()
                

    return mse_sum / len(data_loader.dataset)

# %%
def predict(model, data_loader):
    """Returns an np.array with predictions of the |model| on |data_loader|"""
    model.eval()

    result = np.zeros(len(data_loader.dataset))    
    index = 0
    
    with torch.no_grad():
        for batch_num, (input_ids, attention_mask) in enumerate(data_loader):
            input_ids = input_ids.to(DEVICE)
            attention_mask = attention_mask.to(DEVICE)
                        
            pred = model(input_ids, attention_mask)                        

            result[index : index + pred.shape[0]] = pred.flatten().to("cpu")
            index += pred.shape[0]

    return result

# %%
def train(model, model_path, train_loader, val_loader,
          optimizer, scheduler=None, num_epochs=NUM_EPOCHS):    
    best_val_rmse = None
    best_epoch = 0
    step = 0
    last_eval_step = 0
    eval_period = EVAL_SCHEDULE[0][1]    

    start = time.time()

    for epoch in range(num_epochs):                           
        val_rmse = None         

        for batch_num, (input_ids, attention_mask, target) in enumerate(train_loader):
            input_ids = input_ids.to(DEVICE)
            attention_mask = attention_mask.to(DEVICE)            
            target = target.to(DEVICE)                        

            optimizer.zero_grad()
            
            model.train()

            pred = model(input_ids, attention_mask)
                                                        
            mse = nn.MSELoss(reduction="mean")(pred.flatten(), target)
                        
            mse.backward()

            optimizer.step()
            if scheduler:
                scheduler.step()
            
            if step >= last_eval_step + eval_period:
                # Evaluate the model on val_loader.
                elapsed_seconds = time.time() - start
                num_steps = step - last_eval_step
                print(f"\n{num_steps} steps took {elapsed_seconds:0.3} seconds")
                last_eval_step = step
                
                val_rmse = math.sqrt(eval_mse(model, val_loader))                            

                print(f"Epoch: {epoch} batch_num: {batch_num}", 
                      f"val_rmse: {val_rmse:0.4}")

                for rmse, period in EVAL_SCHEDULE:
                    if val_rmse >= rmse:
                        eval_period = period
                        break                               
                
                if not best_val_rmse or val_rmse < best_val_rmse:                    
                    best_val_rmse = val_rmse
                    best_epoch = epoch
                    torch.save(model.state_dict(), model_path)
                    print(f"New best_val_rmse: {best_val_rmse:0.4}")
                else:       
                    print(f"Still best_val_rmse: {best_val_rmse:0.4}",
                          f"(from epoch {best_epoch})")                                    
                    
                start = time.time()
                                            
            step += 1
                        
    
    return best_val_rmse

# %%
#怪しい
def create_optimizer(model):
    #model.named_parameters():
    #Base -> 205
    #Large -> 397
    named_parameters = list(model.named_parameters())    

    #Base
    # roberta_parameters = named_parameters[:197]    
    # attention_parameters = named_parameters[199:203]
    # regressor_parameters = named_parameters[203:]
    
    #Large
    roberta_parameters = named_parameters[:389]    
    attention_parameters = named_parameters[391:395]
    regressor_parameters = named_parameters[395:]
        
    attention_group = [params for (name, params) in attention_parameters]
    regressor_group = [params for (name, params) in regressor_parameters]

    parameters = []
    parameters.append({"params": attention_group})
    parameters.append({"params": regressor_group})

    for layer_num, (name, params) in enumerate(roberta_parameters):
        weight_decay = 0.0 if "bias" in name else 0.01
        lr = 2e-5
        #roberta-base: 
        # if layer_num >= 69: #4/12layers       
        #     lr = 5e-5
        # if layer_num >= 1f33: #8/12layers
        #     lr = 1e-4
        #roberta-large
        if layer_num >= 133: #8/24layers     
            lr = 5e-5
        if layer_num >= 261: #16/24layers
            lr = 1e-4


        parameters.append({"params": params,
                           "weight_decay": weight_decay,
                           "lr": lr})

    return AdamW(parameters)

# %%
# SEED = 1000
# kfold = KFold(n_splits=NUM_FOLDS, random_state=SEED, shuffle=True)
# for fold, (train_indices, val_indices) in enumerate(kfold.split(train_df)):
#     print(fold)
#     print('------------')
#     print(val_indices)

# %% [markdown]
# # Debug

# %%
model = LitModel().to(DEVICE)
# Out:
# Some weights of RobertaModel were not initialized from the model checkpoint at /content/drive/MyDrive/CommonLit/input/commonlitreadabilityprize/roberta-large-mlm/clrp_roberta_large and are newly initialized: ['roberta.pooler.dense.weight', 'roberta.pooler.dense.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
named_parameters = list(model.named_parameters())
len(named_parameters)
# Out:
# 397

# %%
# for name, param in model.named_parameters():
#     print(name)

# %% [markdown]
# # Train

# %%
# output にフォルダ作成
# !mkdir /content/drive/MyDrive/CommonLit/output/roberta-large-meanpooling-pretrain

# %%
gc.collect()

SEED = 1000
list_val_rmse = []

PATH = "/content/drive/MyDrive/CommonLit/output/roberta-large-meanpooling-pretrain/"

kfold = KFold(n_splits=NUM_FOLDS, random_state=SEED, shuffle=True)

for fold, (train_indices, val_indices) in enumerate(kfold.split(train_df)):    
    print(f"\nFold {fold + 1}/{NUM_FOLDS}")
    model_path = PATH + f"model_{fold + 1}.pth"
        
    set_random_seed(SEED + fold)
    
    train_dataset = LitDataset(train_df.loc[train_indices])    
    val_dataset = LitDataset(train_df.loc[val_indices])    
        
    train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE,
                              drop_last=True, shuffle=True, num_workers=2)    
    val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE,
                            drop_last=False, shuffle=False, num_workers=2)    
        
    set_random_seed(SEED + fold)    
    
    model = LitModel().to(DEVICE)
    
    optimizer = create_optimizer(model)                        
    scheduler = get_cosine_schedule_with_warmup(
        optimizer,
        num_training_steps=NUM_EPOCHS * len(train_loader),
        num_warmup_steps=50)    
    
    list_val_rmse.append(train(model, model_path, train_loader,
                               val_loader, optimizer, scheduler=scheduler))

    del model
    gc.collect()
    
    print("\nPerformance estimates:")
    print(list_val_rmse)
    print("Mean:", np.array(list_val_rmse).mean())
# Out:
# Fold 1/5
# Some weights of RobertaModel were not initialized from the model checkpoint at /content/drive/MyDrive/CommonLit/input/commonlitreadabilityprize/roberta-large-mlm/clrp_roberta_large and are newly initialized: ['roberta.pooler.dense.weight', 'roberta.pooler.dense.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 16 steps took 12.6 seconds
# Epoch: 0 batch_num: 16 val_rmse: 0.9182
# New best_val_rmse: 0.9182
#
# 16 steps took 11.8 seconds
# Epoch: 0 batch_num: 32 val_rmse: 0.726
# New best_val_rmse: 0.726
#
# 16 steps took 11.7 seconds
# Epoch: 0 batch_num: 48 val_rmse: 0.7862
# Still best_val_rmse: 0.726 (from epoch 0)
#
# 16 steps took 11.7 seconds
# Epoch: 0 batch_num: 64 val_rmse: 0.7294
# Still best_val_rmse: 0.726 (from epoch 0)
#
# 16 steps took 11.7 seconds
# Epoch: 0 batch_num: 80 val_rmse: 0.7075
# New best_val_rmse: 0.7075
#
# 16 steps took 11.8 seconds
# Epoch: 0 batch_num: 96 val_rmse: 0.683
# New best_val_rmse: 0.683
#
# 16 steps took 11.8 seconds
# Epoch: 0 batch_num: 112 val_rmse: 0.6963
# Still best_val_rmse: 0.683 (from epoch 0)
#
# 16 steps took 11.7 seconds
# Epoch: 0 batch_num: 128 val_rmse: 0.7718
# Still best_val_rmse: 0.683 (from epoch 0)
#
# 16 steps took 11.7 seconds
# Epoch: 0 batch_num: 144 val_rmse: 0.8384
# Still best_val_rmse: 0.683 (from epoch 0)
#
# 16 steps took 11.7 seconds
# Epoch: 0 batch_num: 160 val_rmse: 0.8016
# Still best_val_rmse: 0.683 (from epoch 0)
#
# 16 steps took 11.7 seconds
# Epoch: 0 batch_num: 176 val_rmse: 0.7551
# Still best_val_rmse: 0.683 (from epoch 0)
#
# 16 steps took 11.8 seconds
# Epoch: 0 batch_num: 192 val_rmse: 0.7276
# Still best_val_rmse: 0.683 (from epoch 0)
#
# 16 steps took 11.7 seconds
# Epoch: 0 batch_num: 208 val_rmse: 0.7246
# Still best_val_rmse: 0.683 (from epoch 0)
#
# 16 steps took 11.7 seconds
# Epoch: 0 batch_num: 224 val_rmse: 0.9294
# Still best_val_rmse: 0.683 (from epoch 0)
#
# 16 steps took 11.7 seconds
# Epoch: 0 batch_num: 240 val_rmse: 0.6013
# New best_val_rmse: 0.6013
#
# 16 steps took 11.8 seconds
# Epoch: 0 batch_num: 256 val_rmse: 0.5919
# New best_val_rmse: 0.5919
#
# 16 steps took 11.8 seconds
# Epoch: 0 batch_num: 272 val_rmse: 0.5995
# Still best_val_rmse: 0.5919 (from epoch 0)
#
# 16 steps took 11.9 seconds
# Epoch: 1 batch_num: 5 val_rmse: 0.599
# Still best_val_rmse: 0.5919 (from epoch 0)
#
# 16 steps took 11.7 seconds
# Epoch: 1 batch_num: 21 val_rmse: 0.5936
# Still best_val_rmse: 0.5919 (from epoch 0)
#
# 16 steps took 11.7 seconds
# Epoch: 1 batch_num: 37 val_rmse: 0.6612
# Still best_val_rmse: 0.5919 (from epoch 0)
#
# 16 steps took 11.7 seconds
# Epoch: 1 batch_num: 53 val_rmse: 0.5589
# New best_val_rmse: 0.5589
#
# 16 steps took 11.8 seconds
# Epoch: 1 batch_num: 69 val_rmse: 0.5594
# Still best_val_rmse: 0.5589 (from epoch 1)
#
# 16 steps took 11.7 seconds
# Epoch: 1 batch_num: 85 val_rmse: 0.6099
# Still best_val_rmse: 0.5589 (from epoch 1)
#
# 16 steps took 11.7 seconds
# Epoch: 1 batch_num: 101 val_rmse: 0.6009
# Still best_val_rmse: 0.5589 (from epoch 1)
#
# 16 steps took 11.7 seconds
# Epoch: 1 batch_num: 117 val_rmse: 0.6248
# Still best_val_rmse: 0.5589 (from epoch 1)
#
# 16 steps took 11.7 seconds
# Epoch: 1 batch_num: 133 val_rmse: 0.5734
# Still best_val_rmse: 0.5589 (from epoch 1)
#
# 16 steps took 11.7 seconds
# Epoch: 1 batch_num: 149 val_rmse: 0.602
# Still best_val_rmse: 0.5589 (from epoch 1)
#
# 16 steps took 11.7 seconds
# Epoch: 1 batch_num: 165 val_rmse: 0.522
# New best_val_rmse: 0.522
#
# 16 steps took 11.7 seconds
# Epoch: 1 batch_num: 181 val_rmse: 0.5941
# Still best_val_rmse: 0.522 (from epoch 1)
#
# 16 steps took 11.7 seconds
# Epoch: 1 batch_num: 197 val_rmse: 0.6014
# Still best_val_rmse: 0.522 (from epoch 1)
#
# 16 steps took 11.7 seconds
# Epoch: 1 batch_num: 213 val_rmse: 0.5649
# Still best_val_rmse: 0.522 (from epoch 1)
#
# 16 steps took 11.7 seconds
# Epoch: 1 batch_num: 229 val_rmse: 0.5372
# Still best_val_rmse: 0.522 (from epoch 1)
#
# 16 steps took 11.7 seconds
# Epoch: 1 batch_num: 245 val_rmse: 0.5668
# Still best_val_rmse: 0.522 (from epoch 1)
#
# 16 steps took 11.7 seconds
# Epoch: 1 batch_num: 261 val_rmse: 0.5371
# Still best_val_rmse: 0.522 (from epoch 1)
#
# 16 steps took 11.7 seconds
# Epoch: 1 batch_num: 277 val_rmse: 0.5192
# New best_val_rmse: 0.5192
#
# 16 steps took 11.9 seconds
# Epoch: 2 batch_num: 10 val_rmse: 0.5267
# Still best_val_rmse: 0.5192 (from epoch 1)
#
# 16 steps took 11.7 seconds
# Epoch: 2 batch_num: 26 val_rmse: 0.51
# New best_val_rmse: 0.51
#
# 16 steps took 11.8 seconds
# Epoch: 2 batch_num: 42 val_rmse: 0.5007
# New best_val_rmse: 0.5007
#
# 16 steps took 11.8 seconds
# Epoch: 2 batch_num: 58 val_rmse: 0.4981
# New best_val_rmse: 0.4981
#
# 8 steps took 5.87 seconds
# Epoch: 2 batch_num: 66 val_rmse: 0.5072
# Still best_val_rmse: 0.4981 (from epoch 2)
#
# 16 steps took 11.7 seconds
# Epoch: 2 batch_num: 82 val_rmse: 0.5153
# Still best_val_rmse: 0.4981 (from epoch 2)
#
# 16 steps took 11.7 seconds
# Epoch: 2 batch_num: 98 val_rmse: 0.5034
# Still best_val_rmse: 0.4981 (from epoch 2)
#
# 16 steps took 11.7 seconds
# Epoch: 2 batch_num: 114 val_rmse: 0.4997
# Still best_val_rmse: 0.4981 (from epoch 2)
#
# 8 steps took 5.87 seconds
# Epoch: 2 batch_num: 122 val_rmse: 0.5046
# Still best_val_rmse: 0.4981 (from epoch 2)
#
# 16 steps took 11.7 seconds
# Epoch: 2 batch_num: 138 val_rmse: 0.5244
# Still best_val_rmse: 0.4981 (from epoch 2)
#
# 16 steps took 11.7 seconds
# Epoch: 2 batch_num: 154 val_rmse: 0.4981
# New best_val_rmse: 0.4981
#
# 8 steps took 5.88 seconds
# Epoch: 2 batch_num: 162 val_rmse: 0.5014
# Still best_val_rmse: 0.4981 (from epoch 2)
#
# 16 steps took 11.7 seconds
# Epoch: 2 batch_num: 178 val_rmse: 0.5165
# Still best_val_rmse: 0.4981 (from epoch 2)
#
# 16 steps took 11.7 seconds
# Epoch: 2 batch_num: 194 val_rmse: 0.5022
# Still best_val_rmse: 0.4981 (from epoch 2)
#
# 16 steps took 11.8 seconds
# Epoch: 2 batch_num: 210 val_rmse: 0.5005
# Still best_val_rmse: 0.4981 (from epoch 2)
#
# 16 steps took 11.7 seconds
# Epoch: 2 batch_num: 226 val_rmse: 0.5019
# Still best_val_rmse: 0.4981 (from epoch 2)
#
# 16 steps took 11.7 seconds
# Epoch: 2 batch_num: 242 val_rmse: 0.4995
# Still best_val_rmse: 0.4981 (from epoch 2)
#
# 8 steps took 5.86 seconds
# Epoch: 2 batch_num: 250 val_rmse: 0.4991
# Still best_val_rmse: 0.4981 (from epoch 2)
#
# 8 steps took 5.86 seconds
# Epoch: 2 batch_num: 258 val_rmse: 0.4992
# Still best_val_rmse: 0.4981 (from epoch 2)
#
# 8 steps took 5.87 seconds
# Epoch: 2 batch_num: 266 val_rmse: 0.4992
# Still best_val_rmse: 0.4981 (from epoch 2)
#
# 8 steps took 5.86 seconds
# Epoch: 2 batch_num: 274 val_rmse: 0.4992
# Still best_val_rmse: 0.4981 (from epoch 2)
#
# 8 steps took 5.86 seconds
# Epoch: 2 batch_num: 282 val_rmse: 0.4992
# Still best_val_rmse: 0.4981 (from epoch 2)
#
# Performance estimates:
# [0.49805953176645995]
# Mean: 0.49805953176645995
#
# Fold 2/5
# Some weights of RobertaModel were not initialized from the model checkpoint at /content/drive/MyDrive/CommonLit/input/commonlitreadabilityprize/roberta-large-mlm/clrp_roberta_large and are newly initialized: ['roberta.pooler.dense.weight', 'roberta.pooler.dense.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 16 steps took 12.6 seconds
# Epoch: 0 batch_num: 16 val_rmse: 1.094
# New best_val_rmse: 1.094
#
# 16 steps took 11.7 seconds
# Epoch: 0 batch_num: 32 val_rmse: 0.7934
# New best_val_rmse: 0.7934
#
# 16 steps took 11.8 seconds
# Epoch: 0 batch_num: 48 val_rmse: 0.8209
# Still best_val_rmse: 0.7934 (from epoch 0)
#
# 16 steps took 11.7 seconds
# Epoch: 0 batch_num: 64 val_rmse: 0.6614
# New best_val_rmse: 0.6614
#
# 16 steps took 11.8 seconds
# Epoch: 0 batch_num: 80 val_rmse: 0.7056
# Still best_val_rmse: 0.6614 (from epoch 0)
#
# 16 steps took 11.8 seconds
# Epoch: 0 batch_num: 96 val_rmse: 0.7514
# Still best_val_rmse: 0.6614 (from epoch 0)
#
# 16 steps took 11.7 seconds
# Epoch: 0 batch_num: 112 val_rmse: 0.7584
# Still best_val_rmse: 0.6614 (from epoch 0)
#
# 16 steps took 11.7 seconds
# Epoch: 0 batch_num: 128 val_rmse: 0.6377
# New best_val_rmse: 0.6377
#
# 16 steps took 11.7 seconds
# Epoch: 0 batch_num: 144 val_rmse: 0.6681
# Still best_val_rmse: 0.6377 (from epoch 0)
#
# 16 steps took 11.7 seconds
# Epoch: 0 batch_num: 160 val_rmse: 0.5553
# New best_val_rmse: 0.5553
#
# 16 steps took 11.8 seconds
# Epoch: 0 batch_num: 176 val_rmse: 0.5553
# New best_val_rmse: 0.5553
#
# 16 steps took 11.8 seconds
# Epoch: 0 batch_num: 192 val_rmse: 0.726
# Still best_val_rmse: 0.5553 (from epoch 0)
#
# 16 steps took 11.7 seconds
# Epoch: 0 batch_num: 208 val_rmse: 0.5607
# Still best_val_rmse: 0.5553 (from epoch 0)
#
# 16 steps took 11.7 seconds
# Epoch: 0 batch_num: 224 val_rmse: 0.6191
# Still best_val_rmse: 0.5553 (from epoch 0)
#
# 16 steps took 11.7 seconds
# Epoch: 0 batch_num: 240 val_rmse: 0.6383
# Still best_val_rmse: 0.5553 (from epoch 0)
#
# 16 steps took 11.7 seconds
# Epoch: 0 batch_num: 256 val_rmse: 0.5566
# Still best_val_rmse: 0.5553 (from epoch 0)
#
# 16 steps took 11.7 seconds
# Epoch: 0 batch_num: 272 val_rmse: 0.5394
# New best_val_rmse: 0.5394
#
# 16 steps took 11.9 seconds
# Epoch: 1 batch_num: 5 val_rmse: 0.5545
# Still best_val_rmse: 0.5394 (from epoch 0)
#
# 16 steps took 11.7 seconds
# Epoch: 1 batch_num: 21 val_rmse: 0.5609
# Still best_val_rmse: 0.5394 (from epoch 0)
#
# 16 steps took 11.7 seconds
# Epoch: 1 batch_num: 37 val_rmse: 0.5227
# New best_val_rmse: 0.5227
#
# 16 steps took 11.8 seconds
# Epoch: 1 batch_num: 53 val_rmse: 0.5085
# New best_val_rmse: 0.5085
#
# 16 steps took 11.8 seconds
# Epoch: 1 batch_num: 69 val_rmse: 0.5303
# Still best_val_rmse: 0.5085 (from epoch 1)
#
# 16 steps took 11.7 seconds
# Epoch: 1 batch_num: 85 val_rmse: 0.5081
# New best_val_rmse: 0.5081
#
# 16 steps took 11.8 seconds
# Epoch: 1 batch_num: 101 val_rmse: 0.5045
# New best_val_rmse: 0.5045
#
# 16 steps took 11.7 seconds
# Epoch: 1 batch_num: 117 val_rmse: 0.5427
# Still best_val_rmse: 0.5045 (from epoch 1)
#
# 16 steps took 11.7 seconds
# Epoch: 1 batch_num: 133 val_rmse: 0.5275
# Still best_val_rmse: 0.5045 (from epoch 1)
#
# 16 steps took 11.7 seconds
# Epoch: 1 batch_num: 149 val_rmse: 0.513
# Still best_val_rmse: 0.5045 (from epoch 1)
#
# 16 steps took 11.7 seconds
# Epoch: 1 batch_num: 165 val_rmse: 0.517
# Still best_val_rmse: 0.5045 (from epoch 1)
#
# 16 steps took 11.7 seconds
# Epoch: 1 batch_num: 181 val_rmse: 0.4967
# New best_val_rmse: 0.4967
#
# 8 steps took 5.89 seconds
# Epoch: 1 batch_num: 189 val_rmse: 0.508
# Still best_val_rmse: 0.4967 (from epoch 1)
#
# 16 steps took 11.8 seconds
# Epoch: 1 batch_num: 205 val_rmse: 0.5134
# Still best_val_rmse: 0.4967 (from epoch 1)
#
# 16 steps took 11.7 seconds
# Epoch: 1 batch_num: 221 val_rmse: 0.4879
# New best_val_rmse: 0.4879
#
# 4 steps took 2.94 seconds
# Epoch: 1 batch_num: 225 val_rmse: 0.5144
# Still best_val_rmse: 0.4879 (from epoch 1)
#
# 16 steps took 11.8 seconds
# Epoch: 1 batch_num: 241 val_rmse: 0.506
# Still best_val_rmse: 0.4879 (from epoch 1)
#
# 16 steps took 11.8 seconds
# Epoch: 1 batch_num: 257 val_rmse: 0.5085
# Still best_val_rmse: 0.4879 (from epoch 1)
#
# 16 steps took 11.7 seconds
# Epoch: 1 batch_num: 273 val_rmse: 0.515
# Still best_val_rmse: 0.4879 (from epoch 1)
#
# 16 steps took 11.9 seconds
# Epoch: 2 batch_num: 6 val_rmse: 0.5037
# Still best_val_rmse: 0.4879 (from epoch 1)
#
# 16 steps took 11.7 seconds
# Epoch: 2 batch_num: 22 val_rmse: 0.4899
# Still best_val_rmse: 0.4879 (from epoch 1)
#
# 4 steps took 2.93 seconds
# Epoch: 2 batch_num: 26 val_rmse: 0.5193
# Still best_val_rmse: 0.4879 (from epoch 1)
#
# 16 steps took 11.8 seconds
# Epoch: 2 batch_num: 42 val_rmse: 0.4835
# New best_val_rmse: 0.4835
#
# 4 steps took 2.95 seconds
# Epoch: 2 batch_num: 46 val_rmse: 0.4863
# Still best_val_rmse: 0.4835 (from epoch 2)
#
# 4 steps took 2.94 seconds
# Epoch: 2 batch_num: 50 val_rmse: 0.4828
# New best_val_rmse: 0.4828
#
# 4 steps took 2.94 seconds
# Epoch: 2 batch_num: 54 val_rmse: 0.4798
# New best_val_rmse: 0.4798
#
# 2 steps took 1.46 seconds
# Epoch: 2 batch_num: 56 val_rmse: 0.4806
# Still best_val_rmse: 0.4798 (from epoch 2)
#
# 4 steps took 2.94 seconds
# Epoch: 2 batch_num: 60 val_rmse: 0.4828
# Still best_val_rmse: 0.4798 (from epoch 2)
#
# 4 steps took 2.94 seconds
# Epoch: 2 batch_num: 64 val_rmse: 0.4781
# New best_val_rmse: 0.4781
#
# 2 steps took 1.47 seconds
# Epoch: 2 batch_num: 66 val_rmse: 0.4777
# New best_val_rmse: 0.4777
#
# 2 steps took 1.45 seconds
# Epoch: 2 batch_num: 68 val_rmse: 0.4857
# Still best_val_rmse: 0.4777 (from epoch 2)
#
# 4 steps took 2.93 seconds
# Epoch: 2 batch_num: 72 val_rmse: 0.4988
# Still best_val_rmse: 0.4777 (from epoch 2)
#
# 8 steps took 5.87 seconds
# Epoch: 2 batch_num: 80 val_rmse: 0.4775
# New best_val_rmse: 0.4775
#
# 2 steps took 1.48 seconds
# Epoch: 2 batch_num: 82 val_rmse: 0.4775
# Still best_val_rmse: 0.4775 (from epoch 2)
#
# 2 steps took 1.46 seconds
# Epoch: 2 batch_num: 84 val_rmse: 0.4791
# Still best_val_rmse: 0.4775 (from epoch 2)
#
# 2 steps took 1.46 seconds
# Epoch: 2 batch_num: 86 val_rmse: 0.4796
# Still best_val_rmse: 0.4775 (from epoch 2)
#
# 2 steps took 1.46 seconds
# Epoch: 2 batch_num: 88 val_rmse: 0.4792
# Still best_val_rmse: 0.4775 (from epoch 2)
#
# 2 steps took 1.46 seconds
# Epoch: 2 batch_num: 90 val_rmse: 0.4808
# Still best_val_rmse: 0.4775 (from epoch 2)
#
# 4 steps took 2.93 seconds
# Epoch: 2 batch_num: 94 val_rmse: 0.4918
# Still best_val_rmse: 0.4775 (from epoch 2)
#
# 8 steps took 5.86 seconds
# Epoch: 2 batch_num: 102 val_rmse: 0.4788
# Still best_val_rmse: 0.4775 (from epoch 2)
#
# 2 steps took 1.45 seconds
# Epoch: 2 batch_num: 104 val_rmse: 0.4778
# Still best_val_rmse: 0.4775 (from epoch 2)
#
# 2 steps took 1.46 seconds
# Epoch: 2 batch_num: 106 val_rmse: 0.4773
# New best_val_rmse: 0.4773
#
# 2 steps took 1.48 seconds
# Epoch: 2 batch_num: 108 val_rmse: 0.4768
# New best_val_rmse: 0.4768
#
# 2 steps took 1.46 seconds
# Epoch: 2 batch_num: 110 val_rmse: 0.4772
# Still best_val_rmse: 0.4768 (from epoch 2)
#
# 2 steps took 1.47 seconds
# Epoch: 2 batch_num: 112 val_rmse: 0.4767
# New best_val_rmse: 0.4767
#
# 2 steps took 1.47 seconds
# Epoch: 2 batch_num: 114 val_rmse: 0.476
# New best_val_rmse: 0.476
#
# 2 steps took 1.46 seconds
# Epoch: 2 batch_num: 116 val_rmse: 0.4761
# Still best_val_rmse: 0.476 (from epoch 2)
#
# 2 steps took 1.46 seconds
# Epoch: 2 batch_num: 118 val_rmse: 0.476
# Still best_val_rmse: 0.476 (from epoch 2)
#
# 2 steps took 1.45 seconds
# Epoch: 2 batch_num: 120 val_rmse: 0.4761
# Still best_val_rmse: 0.476 (from epoch 2)
#
# 2 steps took 1.46 seconds
# Epoch: 2 batch_num: 122 val_rmse: 0.4756
# New best_val_rmse: 0.4756
#
# 2 steps took 1.47 seconds
# Epoch: 2 batch_num: 124 val_rmse: 0.4748
# New best_val_rmse: 0.4748
#
# 2 steps took 1.46 seconds
# Epoch: 2 batch_num: 126 val_rmse: 0.4746
# New best_val_rmse: 0.4746
#
# 2 steps took 1.47 seconds
# Epoch: 2 batch_num: 128 val_rmse: 0.4749
# Still best_val_rmse: 0.4746 (from epoch 2)
#
# 2 steps took 1.46 seconds
# Epoch: 2 batch_num: 130 val_rmse: 0.4748
# Still best_val_rmse: 0.4746 (from epoch 2)
#
# 2 steps took 1.46 seconds
# Epoch: 2 batch_num: 132 val_rmse: 0.4745
# New best_val_rmse: 0.4745
#
# 2 steps took 1.47 seconds
# Epoch: 2 batch_num: 134 val_rmse: 0.4749
# Still best_val_rmse: 0.4745 (from epoch 2)
#
# 2 steps took 1.47 seconds
# Epoch: 2 batch_num: 136 val_rmse: 0.4749
# Still best_val_rmse: 0.4745 (from epoch 2)
#
# 2 steps took 1.46 seconds
# Epoch: 2 batch_num: 138 val_rmse: 0.4737
# New best_val_rmse: 0.4737
#
# 2 steps took 1.47 seconds
# Epoch: 2 batch_num: 140 val_rmse: 0.4748
# Still best_val_rmse: 0.4737 (from epoch 2)
#
# 2 steps took 1.46 seconds
# Epoch: 2 batch_num: 142 val_rmse: 0.479
# Still best_val_rmse: 0.4737 (from epoch 2)
#
# 2 steps took 1.46 seconds
# Epoch: 2 batch_num: 144 val_rmse: 0.4848
# Still best_val_rmse: 0.4737 (from epoch 2)
#
# 4 steps took 2.93 seconds
# Epoch: 2 batch_num: 148 val_rmse: 0.482
# Still best_val_rmse: 0.4737 (from epoch 2)
#
# 4 steps took 2.92 seconds
# Epoch: 2 batch_num: 152 val_rmse: 0.4765
# Still best_val_rmse: 0.4737 (from epoch 2)
#
# 2 steps took 1.46 seconds
# Epoch: 2 batch_num: 154 val_rmse: 0.4749
# Still best_val_rmse: 0.4737 (from epoch 2)
#
# 2 steps took 1.46 seconds
# Epoch: 2 batch_num: 156 val_rmse: 0.4743
# Still best_val_rmse: 0.4737 (from epoch 2)
#
# 2 steps took 1.45 seconds
# Epoch: 2 batch_num: 158 val_rmse: 0.474
# Still best_val_rmse: 0.4737 (from epoch 2)
#
# 2 steps took 1.46 seconds
# Epoch: 2 batch_num: 160 val_rmse: 0.4741
# Still best_val_rmse: 0.4737 (from epoch 2)
#
# 2 steps took 1.46 seconds
# Epoch: 2 batch_num: 162 val_rmse: 0.4743
# Still best_val_rmse: 0.4737 (from epoch 2)
#
# 2 steps took 1.46 seconds
# Epoch: 2 batch_num: 164 val_rmse: 0.4743
# Still best_val_rmse: 0.4737 (from epoch 2)
#
# 2 steps took 1.46 seconds
# Epoch: 2 batch_num: 166 val_rmse: 0.4741
# Still best_val_rmse: 0.4737 (from epoch 2)
#
# 2 steps took 1.46 seconds
# Epoch: 2 batch_num: 168 val_rmse: 0.4741
# Still best_val_rmse: 0.4737 (from epoch 2)
#
# 2 steps took 1.46 seconds
# Epoch: 2 batch_num: 170 val_rmse: 0.474
# Still best_val_rmse: 0.4737 (from epoch 2)
#
# 2 steps took 1.46 seconds
# Epoch: 2 batch_num: 172 val_rmse: 0.4742
# Still best_val_rmse: 0.4737 (from epoch 2)
#
# 2 steps took 1.46 seconds
# Epoch: 2 batch_num: 174 val_rmse: 0.4745
# Still best_val_rmse: 0.4737 (from epoch 2)
#
# 2 steps took 1.46 seconds
# Epoch: 2 batch_num: 176 val_rmse: 0.4744
# Still best_val_rmse: 0.4737 (from epoch 2)
#
# 2 steps took 1.46 seconds
# Epoch: 2 batch_num: 178 val_rmse: 0.474
# Still best_val_rmse: 0.4737 (from epoch 2)
#
# 2 steps took 1.46 seconds
# Epoch: 2 batch_num: 180 val_rmse: 0.4739
# Still best_val_rmse: 0.4737 (from epoch 2)
#
# 2 steps took 1.46 seconds
# Epoch: 2 batch_num: 182 val_rmse: 0.4741
# Still best_val_rmse: 0.4737 (from epoch 2)
#
# 2 steps took 1.45 seconds
# Epoch: 2 batch_num: 184 val_rmse: 0.4748
# Still best_val_rmse: 0.4737 (from epoch 2)
#
# 2 steps took 1.46 seconds
# Epoch: 2 batch_num: 186 val_rmse: 0.4758
# Still best_val_rmse: 0.4737 (from epoch 2)
#
# 2 steps took 1.46 seconds
# Epoch: 2 batch_num: 188 val_rmse: 0.4767
# Still best_val_rmse: 0.4737 (from epoch 2)
#
# 2 steps took 1.45 seconds
# Epoch: 2 batch_num: 190 val_rmse: 0.4773
# Still best_val_rmse: 0.4737 (from epoch 2)
#
# 2 steps took 1.46 seconds
# Epoch: 2 batch_num: 192 val_rmse: 0.4777
# Still best_val_rmse: 0.4737 (from epoch 2)
#
# 2 steps took 1.46 seconds
# Epoch: 2 batch_num: 194 val_rmse: 0.4775
# Still best_val_rmse: 0.4737 (from epoch 2)
#
# 2 steps took 1.46 seconds
# Epoch: 2 batch_num: 196 val_rmse: 0.4777
# Still best_val_rmse: 0.4737 (from epoch 2)
#
# 2 steps took 1.46 seconds
# Epoch: 2 batch_num: 198 val_rmse: 0.477
# Still best_val_rmse: 0.4737 (from epoch 2)
#
# 2 steps took 1.46 seconds
# Epoch: 2 batch_num: 200 val_rmse: 0.476
# Still best_val_rmse: 0.4737 (from epoch 2)
#
# 2 steps took 1.46 seconds
# Epoch: 2 batch_num: 202 val_rmse: 0.4751
# Still best_val_rmse: 0.4737 (from epoch 2)
#
# 2 steps took 1.46 seconds
# Epoch: 2 batch_num: 204 val_rmse: 0.4745
# Still best_val_rmse: 0.4737 (from epoch 2)
#
# 2 steps took 1.46 seconds
# Epoch: 2 batch_num: 206 val_rmse: 0.4739
# Still best_val_rmse: 0.4737 (from epoch 2)
#
# 2 steps took 1.46 seconds
# Epoch: 2 batch_num: 208 val_rmse: 0.4738
# Still best_val_rmse: 0.4737 (from epoch 2)
#
# 2 steps took 1.46 seconds
# Epoch: 2 batch_num: 210 val_rmse: 0.4737
# Still best_val_rmse: 0.4737 (from epoch 2)
#
# 2 steps took 1.46 seconds
# Epoch: 2 batch_num: 212 val_rmse: 0.4737
# Still best_val_rmse: 0.4737 (from epoch 2)
#
# 2 steps took 1.46 seconds
# Epoch: 2 batch_num: 214 val_rmse: 0.4738
# Still best_val_rmse: 0.4737 (from epoch 2)
#
# 2 steps took 1.46 seconds
# Epoch: 2 batch_num: 216 val_rmse: 0.4739
# Still best_val_rmse: 0.4737 (from epoch 2)
#
# 2 steps took 1.46 seconds
# Epoch: 2 batch_num: 218 val_rmse: 0.4739
# Still best_val_rmse: 0.4737 (from epoch 2)
#
# 2 steps took 1.46 seconds
# Epoch: 2 batch_num: 220 val_rmse: 0.4739
# Still best_val_rmse: 0.4737 (from epoch 2)
#
# 2 steps took 1.46 seconds
# Epoch: 2 batch_num: 222 val_rmse: 0.4739
# Still best_val_rmse: 0.4737 (from epoch 2)
#
# 2 steps took 1.46 seconds
# Epoch: 2 batch_num: 224 val_rmse: 0.4739
# Still best_val_rmse: 0.4737 (from epoch 2)
#
# 2 steps took 1.46 seconds
# Epoch: 2 batch_num: 226 val_rmse: 0.4739
# Still best_val_rmse: 0.4737 (from epoch 2)
#
# 2 steps took 1.46 seconds
# Epoch: 2 batch_num: 228 val_rmse: 0.4739
# Still best_val_rmse: 0.4737 (from epoch 2)
#
# 2 steps took 1.46 seconds
# Epoch: 2 batch_num: 230 val_rmse: 0.4739
# Still best_val_rmse: 0.4737 (from epoch 2)
#
# 2 steps took 1.46 seconds
# Epoch: 2 batch_num: 232 val_rmse: 0.474
# Still best_val_rmse: 0.4737 (from epoch 2)
#
# 2 steps took 1.45 seconds
# Epoch: 2 batch_num: 234 val_rmse: 0.4741
# Still best_val_rmse: 0.4737 (from epoch 2)
#
# 2 steps took 1.46 seconds
# Epoch: 2 batch_num: 236 val_rmse: 0.4743
# Still best_val_rmse: 0.4737 (from epoch 2)
#
# 2 steps took 1.46 seconds
# Epoch: 2 batch_num: 238 val_rmse: 0.4745
# Still best_val_rmse: 0.4737 (from epoch 2)
#
# 2 steps took 1.46 seconds
# Epoch: 2 batch_num: 240 val_rmse: 0.4748
# Still best_val_rmse: 0.4737 (from epoch 2)
#
# 2 steps took 1.46 seconds
# Epoch: 2 batch_num: 242 val_rmse: 0.475
# Still best_val_rmse: 0.4737 (from epoch 2)
#
# 2 steps took 1.46 seconds
# Epoch: 2 batch_num: 244 val_rmse: 0.4752
# Still best_val_rmse: 0.4737 (from epoch 2)
#
# 2 steps took 1.46 seconds
# Epoch: 2 batch_num: 246 val_rmse: 0.4755
# Still best_val_rmse: 0.4737 (from epoch 2)
#
# 2 steps took 1.46 seconds
# Epoch: 2 batch_num: 248 val_rmse: 0.4757
# Still best_val_rmse: 0.4737 (from epoch 2)
#
# 2 steps took 1.46 seconds
# Epoch: 2 batch_num: 250 val_rmse: 0.4759
# Still best_val_rmse: 0.4737 (from epoch 2)
#
# 2 steps took 1.46 seconds
# Epoch: 2 batch_num: 252 val_rmse: 0.476
# Still best_val_rmse: 0.4737 (from epoch 2)
#
# 2 steps took 1.46 seconds
# Epoch: 2 batch_num: 254 val_rmse: 0.4761
# Still best_val_rmse: 0.4737 (from epoch 2)
#
# 2 steps took 1.46 seconds
# Epoch: 2 batch_num: 256 val_rmse: 0.4761
# Still best_val_rmse: 0.4737 (from epoch 2)
#
# 2 steps took 1.46 seconds
# Epoch: 2 batch_num: 258 val_rmse: 0.4762
# Still best_val_rmse: 0.4737 (from epoch 2)
#
# 2 steps took 1.46 seconds
# Epoch: 2 batch_num: 260 val_rmse: 0.4762
# Still best_val_rmse: 0.4737 (from epoch 2)
#
# 2 steps took 1.46 seconds
# Epoch: 2 batch_num: 262 val_rmse: 0.4761
# Still best_val_rmse: 0.4737 (from epoch 2)
#
# 2 steps took 1.46 seconds
# Epoch: 2 batch_num: 264 val_rmse: 0.4761
# Still best_val_rmse: 0.4737 (from epoch 2)
#
# 2 steps took 1.46 seconds
# Epoch: 2 batch_num: 266 val_rmse: 0.4761
# Still best_val_rmse: 0.4737 (from epoch 2)
#
# 2 steps took 1.46 seconds
# Epoch: 2 batch_num: 268 val_rmse: 0.4761
# Still best_val_rmse: 0.4737 (from epoch 2)
#
# 2 steps took 1.46 seconds
# Epoch: 2 batch_num: 270 val_rmse: 0.4761
# Still best_val_rmse: 0.4737 (from epoch 2)
#
# 2 steps took 1.46 seconds
# Epoch: 2 batch_num: 272 val_rmse: 0.4761
# Still best_val_rmse: 0.4737 (from epoch 2)
#
# 2 steps took 1.46 seconds
# Epoch: 2 batch_num: 274 val_rmse: 0.4761
# Still best_val_rmse: 0.4737 (from epoch 2)
#
# 2 steps took 1.46 seconds
# Epoch: 2 batch_num: 276 val_rmse: 0.4761
# Still best_val_rmse: 0.4737 (from epoch 2)
#
# 2 steps took 1.46 seconds
# Epoch: 2 batch_num: 278 val_rmse: 0.4761
# Still best_val_rmse: 0.4737 (from epoch 2)
#
# 2 steps took 1.46 seconds
# Epoch: 2 batch_num: 280 val_rmse: 0.4761
# Still best_val_rmse: 0.4737 (from epoch 2)
#
# 2 steps took 1.46 seconds
# Epoch: 2 batch_num: 282 val_rmse: 0.4761
# Still best_val_rmse: 0.4737 (from epoch 2)
#
# Performance estimates:
# [0.49805953176645995, 0.4736856332245972]
# Mean: 0.48587258249552856
#
# Fold 3/5
# Some weights of RobertaModel were not initialized from the model checkpoint at /content/drive/MyDrive/CommonLit/input/commonlitreadabilityprize/roberta-large-mlm/clrp_roberta_large and are newly initialized: ['roberta.pooler.dense.weight', 'roberta.pooler.dense.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 16 steps took 12.6 seconds
# Epoch: 0 batch_num: 16 val_rmse: 1.031
# New best_val_rmse: 1.031
#
# 16 steps took 11.8 seconds
# Epoch: 0 batch_num: 32 val_rmse: 0.884
# New best_val_rmse: 0.884
#
# 16 steps took 11.8 seconds
# Epoch: 0 batch_num: 48 val_rmse: 0.8072
# New best_val_rmse: 0.8072
#
# 16 steps took 11.7 seconds
# Epoch: 0 batch_num: 64 val_rmse: 0.6842
# New best_val_rmse: 0.6842
#
# 16 steps took 11.8 seconds
# Epoch: 0 batch_num: 80 val_rmse: 0.6592
# New best_val_rmse: 0.6592
#
# 16 steps took 11.8 seconds
# Epoch: 0 batch_num: 96 val_rmse: 0.7188
# Still best_val_rmse: 0.6592 (from epoch 0)
#
# 16 steps took 11.7 seconds
# Epoch: 0 batch_num: 112 val_rmse: 0.6956
# Still best_val_rmse: 0.6592 (from epoch 0)
#
# 16 steps took 11.7 seconds
# Epoch: 0 batch_num: 128 val_rmse: 0.8755
# Still best_val_rmse: 0.6592 (from epoch 0)
#
# 16 steps took 11.7 seconds
# Epoch: 0 batch_num: 144 val_rmse: 0.8951
# Still best_val_rmse: 0.6592 (from epoch 0)
#
# 16 steps took 11.7 seconds
# Epoch: 0 batch_num: 160 val_rmse: 0.6032
# New best_val_rmse: 0.6032
#
# 16 steps took 11.8 seconds
# Epoch: 0 batch_num: 176 val_rmse: 0.6932
# Still best_val_rmse: 0.6032 (from epoch 0)
#
# 16 steps took 11.8 seconds
# Epoch: 0 batch_num: 192 val_rmse: 0.6937
# Still best_val_rmse: 0.6032 (from epoch 0)
#
# 16 steps took 11.7 seconds
# Epoch: 0 batch_num: 208 val_rmse: 0.607
# Still best_val_rmse: 0.6032 (from epoch 0)
#
# 16 steps took 11.7 seconds
# Epoch: 0 batch_num: 224 val_rmse: 0.6002
# New best_val_rmse: 0.6002
#
# 16 steps took 11.8 seconds
# Epoch: 0 batch_num: 240 val_rmse: 0.5899
# New best_val_rmse: 0.5899
#
# 16 steps took 11.7 seconds
# Epoch: 0 batch_num: 256 val_rmse: 0.5368
# New best_val_rmse: 0.5368
#
# 16 steps took 11.8 seconds
# Epoch: 0 batch_num: 272 val_rmse: 0.5355
# New best_val_rmse: 0.5355
#
# 16 steps took 11.9 seconds
# Epoch: 1 batch_num: 5 val_rmse: 0.529
# New best_val_rmse: 0.529
#
# 16 steps took 11.8 seconds
# Epoch: 1 batch_num: 21 val_rmse: 0.5238
# New best_val_rmse: 0.5238
#
# 16 steps took 11.8 seconds
# Epoch: 1 batch_num: 37 val_rmse: 0.5354
# Still best_val_rmse: 0.5238 (from epoch 1)
#
# 16 steps took 11.7 seconds
# Epoch: 1 batch_num: 53 val_rmse: 0.5469
# Still best_val_rmse: 0.5238 (from epoch 1)
#
# 16 steps took 11.7 seconds
# Epoch: 1 batch_num: 69 val_rmse: 0.5508
# Still best_val_rmse: 0.5238 (from epoch 1)
#
# 16 steps took 11.7 seconds
# Epoch: 1 batch_num: 85 val_rmse: 0.5275
# Still best_val_rmse: 0.5238 (from epoch 1)
#
# 16 steps took 11.7 seconds
# Epoch: 1 batch_num: 101 val_rmse: 0.5337
# Still best_val_rmse: 0.5238 (from epoch 1)
#
# 16 steps took 11.7 seconds
# Epoch: 1 batch_num: 117 val_rmse: 0.5338
# Still best_val_rmse: 0.5238 (from epoch 1)
#
# 16 steps took 11.7 seconds
# Epoch: 1 batch_num: 133 val_rmse: 0.5337
# Still best_val_rmse: 0.5238 (from epoch 1)
#
# 16 steps took 11.7 seconds
# Epoch: 1 batch_num: 149 val_rmse: 0.5093
# New best_val_rmse: 0.5093
#
# 16 steps took 11.8 seconds
# Epoch: 1 batch_num: 165 val_rmse: 0.508
# New best_val_rmse: 0.508
#
# 16 steps took 11.8 seconds
# Epoch: 1 batch_num: 181 val_rmse: 0.5124
# Still best_val_rmse: 0.508 (from epoch 1)
#
# 16 steps took 11.8 seconds
# Epoch: 1 batch_num: 197 val_rmse: 0.5038
# New best_val_rmse: 0.5038
#
# 16 steps took 11.8 seconds
# Epoch: 1 batch_num: 213 val_rmse: 0.5048
# Still best_val_rmse: 0.5038 (from epoch 1)
#
# 16 steps took 11.8 seconds
# Epoch: 1 batch_num: 229 val_rmse: 0.5044
# Still best_val_rmse: 0.5038 (from epoch 1)
#
# 16 steps took 11.7 seconds
# Epoch: 1 batch_num: 245 val_rmse: 0.5068
# Still best_val_rmse: 0.5038 (from epoch 1)
#
# 16 steps took 11.7 seconds
# Epoch: 1 batch_num: 261 val_rmse: 0.494
# New best_val_rmse: 0.494
#
# 8 steps took 5.88 seconds
# Epoch: 1 batch_num: 269 val_rmse: 0.5004
# Still best_val_rmse: 0.494 (from epoch 1)
#
# 16 steps took 11.9 seconds
# Epoch: 2 batch_num: 2 val_rmse: 0.5022
# Still best_val_rmse: 0.494 (from epoch 1)
#
# 16 steps took 11.7 seconds
# Epoch: 2 batch_num: 18 val_rmse: 0.4897
# New best_val_rmse: 0.4897
#
# 4 steps took 2.93 seconds
# Epoch: 2 batch_num: 22 val_rmse: 0.5142
# Still best_val_rmse: 0.4897 (from epoch 2)
#
# 16 steps took 11.8 seconds
# Epoch: 2 batch_num: 38 val_rmse: 0.48
# New best_val_rmse: 0.48
#
# 2 steps took 1.47 seconds
# Epoch: 2 batch_num: 40 val_rmse: 0.4781
# New best_val_rmse: 0.4781
#
# 2 steps took 1.46 seconds
# Epoch: 2 batch_num: 42 val_rmse: 0.4801
# Still best_val_rmse: 0.4781 (from epoch 2)
#
# 4 steps took 2.96 seconds
# Epoch: 2 batch_num: 46 val_rmse: 0.4892
# Still best_val_rmse: 0.4781 (from epoch 2)
#
# 4 steps took 2.93 seconds
# Epoch: 2 batch_num: 50 val_rmse: 0.4813
# Still best_val_rmse: 0.4781 (from epoch 2)
#
# 4 steps took 2.92 seconds
# Epoch: 2 batch_num: 54 val_rmse: 0.4814
# Still best_val_rmse: 0.4781 (from epoch 2)
#
# 4 steps took 2.92 seconds
# Epoch: 2 batch_num: 58 val_rmse: 0.4786
# Still best_val_rmse: 0.4781 (from epoch 2)
#
# 2 steps took 1.46 seconds
# Epoch: 2 batch_num: 60 val_rmse: 0.48
# Still best_val_rmse: 0.4781 (from epoch 2)
#
# 2 steps took 1.46 seconds
# Epoch: 2 batch_num: 62 val_rmse: 0.4935
# Still best_val_rmse: 0.4781 (from epoch 2)
#
# 8 steps took 5.86 seconds
# Epoch: 2 batch_num: 70 val_rmse: 0.4881
# Still best_val_rmse: 0.4781 (from epoch 2)
#
# 4 steps took 2.93 seconds
# Epoch: 2 batch_num: 74 val_rmse: 0.4888
# Still best_val_rmse: 0.4781 (from epoch 2)
#
# 4 steps took 2.93 seconds
# Epoch: 2 batch_num: 78 val_rmse: 0.4922
# Still best_val_rmse: 0.4781 (from epoch 2)
#
# 8 steps took 5.86 seconds
# Epoch: 2 batch_num: 86 val_rmse: 0.4925
# Still best_val_rmse: 0.4781 (from epoch 2)
#
# 8 steps took 5.86 seconds
# Epoch: 2 batch_num: 94 val_rmse: 0.4955
# Still best_val_rmse: 0.4781 (from epoch 2)
#
# 8 steps took 5.88 seconds
# Epoch: 2 batch_num: 102 val_rmse: 0.4955
# Still best_val_rmse: 0.4781 (from epoch 2)
#
# 8 steps took 5.86 seconds
# Epoch: 2 batch_num: 110 val_rmse: 0.4906
# Still best_val_rmse: 0.4781 (from epoch 2)
#
# 8 steps took 5.86 seconds
# Epoch: 2 batch_num: 118 val_rmse: 0.4828
# Still best_val_rmse: 0.4781 (from epoch 2)
#
# 4 steps took 2.93 seconds
# Epoch: 2 batch_num: 122 val_rmse: 0.4836
# Still best_val_rmse: 0.4781 (from epoch 2)
#
# 4 steps took 2.93 seconds
# Epoch: 2 batch_num: 126 val_rmse: 0.4857
# Still best_val_rmse: 0.4781 (from epoch 2)
#
# 4 steps took 2.93 seconds
# Epoch: 2 batch_num: 130 val_rmse: 0.4889
# Still best_val_rmse: 0.4781 (from epoch 2)
#
# 4 steps took 2.93 seconds
# Epoch: 2 batch_num: 134 val_rmse: 0.4899
# Still best_val_rmse: 0.4781 (from epoch 2)
#
# 4 steps took 2.93 seconds
# Epoch: 2 batch_num: 138 val_rmse: 0.4879
# Still best_val_rmse: 0.4781 (from epoch 2)
#
# 4 steps took 2.93 seconds
# Epoch: 2 batch_num: 142 val_rmse: 0.4857
# Still best_val_rmse: 0.4781 (from epoch 2)
#
# 4 steps took 2.92 seconds
# Epoch: 2 batch_num: 146 val_rmse: 0.4854
# Still best_val_rmse: 0.4781 (from epoch 2)
#
# 4 steps took 2.93 seconds
# Epoch: 2 batch_num: 150 val_rmse: 0.4856
# Still best_val_rmse: 0.4781 (from epoch 2)
#
# 4 steps took 2.92 seconds
# Epoch: 2 batch_num: 154 val_rmse: 0.4851
# Still best_val_rmse: 0.4781 (from epoch 2)
#
# 4 steps took 2.93 seconds
# Epoch: 2 batch_num: 158 val_rmse: 0.4848
# Still best_val_rmse: 0.4781 (from epoch 2)
#
# 4 steps took 2.92 seconds
# Epoch: 2 batch_num: 162 val_rmse: 0.4847
# Still best_val_rmse: 0.4781 (from epoch 2)
#
# 4 steps took 2.92 seconds
# Epoch: 2 batch_num: 166 val_rmse: 0.4875
# Still best_val_rmse: 0.4781 (from epoch 2)
#
# 4 steps took 2.93 seconds
# Epoch: 2 batch_num: 170 val_rmse: 0.4863
# Still best_val_rmse: 0.4781 (from epoch 2)
#
# 4 steps took 2.93 seconds
# Epoch: 2 batch_num: 174 val_rmse: 0.4851
# Still best_val_rmse: 0.4781 (from epoch 2)
#
# 4 steps took 2.93 seconds
# Epoch: 2 batch_num: 178 val_rmse: 0.4835
# Still best_val_rmse: 0.4781 (from epoch 2)
#
# 4 steps took 2.93 seconds
# Epoch: 2 batch_num: 182 val_rmse: 0.4835
# Still best_val_rmse: 0.4781 (from epoch 2)
#
# 4 steps took 2.92 seconds
# Epoch: 2 batch_num: 186 val_rmse: 0.4842
# Still best_val_rmse: 0.4781 (from epoch 2)
#
# 4 steps took 2.92 seconds
# Epoch: 2 batch_num: 190 val_rmse: 0.4848
# Still best_val_rmse: 0.4781 (from epoch 2)
#
# 4 steps took 2.93 seconds
# Epoch: 2 batch_num: 194 val_rmse: 0.4855
# Still best_val_rmse: 0.4781 (from epoch 2)
#
# 4 steps took 2.93 seconds
# Epoch: 2 batch_num: 198 val_rmse: 0.4865
# Still best_val_rmse: 0.4781 (from epoch 2)
#
# 4 steps took 2.93 seconds
# Epoch: 2 batch_num: 202 val_rmse: 0.4876
# Still best_val_rmse: 0.4781 (from epoch 2)
#
# 4 steps took 2.92 seconds
# Epoch: 2 batch_num: 206 val_rmse: 0.4877
# Still best_val_rmse: 0.4781 (from epoch 2)
#
# 4 steps took 2.92 seconds
# Epoch: 2 batch_num: 210 val_rmse: 0.489
# Still best_val_rmse: 0.4781 (from epoch 2)
#
# 4 steps took 2.93 seconds
# Epoch: 2 batch_num: 214 val_rmse: 0.4895
# Still best_val_rmse: 0.4781 (from epoch 2)
#
# 4 steps took 2.92 seconds
# Epoch: 2 batch_num: 218 val_rmse: 0.4901
# Still best_val_rmse: 0.4781 (from epoch 2)
#
# 8 steps took 5.86 seconds
# Epoch: 2 batch_num: 226 val_rmse: 0.4892
# Still best_val_rmse: 0.4781 (from epoch 2)
#
# 4 steps took 2.93 seconds
# Epoch: 2 batch_num: 230 val_rmse: 0.489
# Still best_val_rmse: 0.4781 (from epoch 2)
#
# 4 steps took 2.93 seconds
# Epoch: 2 batch_num: 234 val_rmse: 0.4886
# Still best_val_rmse: 0.4781 (from epoch 2)
#
# 4 steps took 2.93 seconds
# Epoch: 2 batch_num: 238 val_rmse: 0.488
# Still best_val_rmse: 0.4781 (from epoch 2)
#
# 4 steps took 2.93 seconds
# Epoch: 2 batch_num: 242 val_rmse: 0.4875
# Still best_val_rmse: 0.4781 (from epoch 2)
#
# 4 steps took 2.93 seconds
# Epoch: 2 batch_num: 246 val_rmse: 0.4877
# Still best_val_rmse: 0.4781 (from epoch 2)
#
# 4 steps took 2.92 seconds
# Epoch: 2 batch_num: 250 val_rmse: 0.4877
# Still best_val_rmse: 0.4781 (from epoch 2)
#
# 4 steps took 2.92 seconds
# Epoch: 2 batch_num: 254 val_rmse: 0.4878
# Still best_val_rmse: 0.4781 (from epoch 2)
#
# 4 steps took 2.93 seconds
# Epoch: 2 batch_num: 258 val_rmse: 0.4878
# Still best_val_rmse: 0.4781 (from epoch 2)
#
# 4 steps took 2.92 seconds
# Epoch: 2 batch_num: 262 val_rmse: 0.4878
# Still best_val_rmse: 0.4781 (from epoch 2)
#
# 4 steps took 2.92 seconds
# Epoch: 2 batch_num: 266 val_rmse: 0.4878
# Still best_val_rmse: 0.4781 (from epoch 2)
#
# 4 steps took 2.93 seconds
# Epoch: 2 batch_num: 270 val_rmse: 0.4877
# Still best_val_rmse: 0.4781 (from epoch 2)
#
# 4 steps took 2.93 seconds
# Epoch: 2 batch_num: 274 val_rmse: 0.4877
# Still best_val_rmse: 0.4781 (from epoch 2)
#
# 4 steps took 2.93 seconds
# Epoch: 2 batch_num: 278 val_rmse: 0.4877
# Still best_val_rmse: 0.4781 (from epoch 2)
#
# 4 steps took 2.92 seconds
# Epoch: 2 batch_num: 282 val_rmse: 0.4877
# Still best_val_rmse: 0.4781 (from epoch 2)
#
# Performance estimates:
# [0.49805953176645995, 0.4736856332245972, 0.47809673197663416]
# Mean: 0.4832806323225638
#
# Fold 4/5
# Some weights of RobertaModel were not initialized from the model checkpoint at /content/drive/MyDrive/CommonLit/input/commonlitreadabilityprize/roberta-large-mlm/clrp_roberta_large and are newly initialized: ['roberta.pooler.dense.weight', 'roberta.pooler.dense.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 16 steps took 12.6 seconds
# Epoch: 0 batch_num: 16 val_rmse: 0.9127
# New best_val_rmse: 0.9127
#
# 16 steps took 11.8 seconds
# Epoch: 0 batch_num: 32 val_rmse: 0.7297
# New best_val_rmse: 0.7297
#
# 16 steps took 11.8 seconds
# Epoch: 0 batch_num: 48 val_rmse: 0.7346
# Still best_val_rmse: 0.7297 (from epoch 0)
#
# 16 steps took 11.7 seconds
# Epoch: 0 batch_num: 64 val_rmse: 0.7212
# New best_val_rmse: 0.7212
#
# 16 steps took 11.8 seconds
# Epoch: 0 batch_num: 80 val_rmse: 0.7795
# Still best_val_rmse: 0.7212 (from epoch 0)
#
# 16 steps took 11.7 seconds
# Epoch: 0 batch_num: 96 val_rmse: 0.7218
# Still best_val_rmse: 0.7212 (from epoch 0)
#
# 16 steps took 11.7 seconds
# Epoch: 0 batch_num: 112 val_rmse: 0.6614
# New best_val_rmse: 0.6614
#
# 16 steps took 11.8 seconds
# Epoch: 0 batch_num: 128 val_rmse: 0.7503
# Still best_val_rmse: 0.6614 (from epoch 0)
#
# 16 steps took 11.7 seconds
# Epoch: 0 batch_num: 144 val_rmse: 0.6706
# Still best_val_rmse: 0.6614 (from epoch 0)
#
# 16 steps took 11.7 seconds
# Epoch: 0 batch_num: 160 val_rmse: 0.7849
# Still best_val_rmse: 0.6614 (from epoch 0)
#
# 16 steps took 11.7 seconds
# Epoch: 0 batch_num: 176 val_rmse: 0.9433
# Still best_val_rmse: 0.6614 (from epoch 0)
#
# 16 steps took 11.7 seconds
# Epoch: 0 batch_num: 192 val_rmse: 1.021
# Still best_val_rmse: 0.6614 (from epoch 0)
#
# 16 steps took 11.7 seconds
# Epoch: 0 batch_num: 208 val_rmse: 1.031
# Still best_val_rmse: 0.6614 (from epoch 0)
#
# 16 steps took 11.7 seconds
# Epoch: 0 batch_num: 224 val_rmse: 0.9664
# Still best_val_rmse: 0.6614 (from epoch 0)
#
# 16 steps took 11.7 seconds
# Epoch: 0 batch_num: 240 val_rmse: 1.032
# Still best_val_rmse: 0.6614 (from epoch 0)
#
# 16 steps took 11.7 seconds
# Epoch: 0 batch_num: 256 val_rmse: 1.023
# Still best_val_rmse: 0.6614 (from epoch 0)
#
# 16 steps took 11.7 seconds
# Epoch: 0 batch_num: 272 val_rmse: 1.028
# Still best_val_rmse: 0.6614 (from epoch 0)
#
# 16 steps took 11.9 seconds
# Epoch: 1 batch_num: 5 val_rmse: 1.022
# Still best_val_rmse: 0.6614 (from epoch 0)
#
# 16 steps took 11.7 seconds
# Epoch: 1 batch_num: 21 val_rmse: 1.055
# Still best_val_rmse: 0.6614 (from epoch 0)
#
# 16 steps took 11.7 seconds
# Epoch: 1 batch_num: 37 val_rmse: 1.022
# Still best_val_rmse: 0.6614 (from epoch 0)
#
# 16 steps took 11.8 seconds
# Epoch: 1 batch_num: 53 val_rmse: 1.021
# Still best_val_rmse: 0.6614 (from epoch 0)
#
# 16 steps took 11.7 seconds
# Epoch: 1 batch_num: 69 val_rmse: 1.032
# Still best_val_rmse: 0.6614 (from epoch 0)
#
# 16 steps took 11.7 seconds
# Epoch: 1 batch_num: 85 val_rmse: 1.068
# Still best_val_rmse: 0.6614 (from epoch 0)
#
# 16 steps took 11.7 seconds
# Epoch: 1 batch_num: 101 val_rmse: 1.049
# Still best_val_rmse: 0.6614 (from epoch 0)
#
# 16 steps took 11.7 seconds
# Epoch: 1 batch_num: 117 val_rmse: 1.027
# Still best_val_rmse: 0.6614 (from epoch 0)
#
# 16 steps took 11.7 seconds
# Epoch: 1 batch_num: 133 val_rmse: 1.021
# Still best_val_rmse: 0.6614 (from epoch 0)
#
# 16 steps took 11.7 seconds
# Epoch: 1 batch_num: 149 val_rmse: 1.021
# Still best_val_rmse: 0.6614 (from epoch 0)
#
# 16 steps took 11.8 seconds
# Epoch: 1 batch_num: 165 val_rmse: 1.027
# Still best_val_rmse: 0.6614 (from epoch 0)
#
# 16 steps took 11.7 seconds
# Epoch: 1 batch_num: 181 val_rmse: 1.039
# Still best_val_rmse: 0.6614 (from epoch 0)
#
# 16 steps took 11.8 seconds
# Epoch: 1 batch_num: 197 val_rmse: 1.03
# Still best_val_rmse: 0.6614 (from epoch 0)
#
# 16 steps took 11.7 seconds
# Epoch: 1 batch_num: 213 val_rmse: 1.026
# Still best_val_rmse: 0.6614 (from epoch 0)
#
# 16 steps took 11.7 seconds
# Epoch: 1 batch_num: 229 val_rmse: 1.032
# Still best_val_rmse: 0.6614 (from epoch 0)
#
# 16 steps took 11.7 seconds
# Epoch: 1 batch_num: 245 val_rmse: 1.023
# Still best_val_rmse: 0.6614 (from epoch 0)
#
# 16 steps took 11.7 seconds
# Epoch: 1 batch_num: 261 val_rmse: 1.021
# Still best_val_rmse: 0.6614 (from epoch 0)
#
# 16 steps took 11.7 seconds
# Epoch: 1 batch_num: 277 val_rmse: 1.021
# Still best_val_rmse: 0.6614 (from epoch 0)
#
# 16 steps took 11.9 seconds
# Epoch: 2 batch_num: 10 val_rmse: 1.022
# Still best_val_rmse: 0.6614 (from epoch 0)
#
# 16 steps took 11.7 seconds
# Epoch: 2 batch_num: 26 val_rmse: 1.021
# Still best_val_rmse: 0.6614 (from epoch 0)
#
# 16 steps took 11.7 seconds
# Epoch: 2 batch_num: 42 val_rmse: 1.021
# Still best_val_rmse: 0.6614 (from epoch 0)
#
# 16 steps took 11.7 seconds
# Epoch: 2 batch_num: 58 val_rmse: 1.021
# Still best_val_rmse: 0.6614 (from epoch 0)
#
# 16 steps took 11.7 seconds
# Epoch: 2 batch_num: 74 val_rmse: 1.022
# Still best_val_rmse: 0.6614 (from epoch 0)
#
# 16 steps took 11.7 seconds
# Epoch: 2 batch_num: 90 val_rmse: 1.025
# Still best_val_rmse: 0.6614 (from epoch 0)
#
# 16 steps took 11.7 seconds
# Epoch: 2 batch_num: 106 val_rmse: 1.022
# Still best_val_rmse: 0.6614 (from epoch 0)
#
# 16 steps took 11.7 seconds
# Epoch: 2 batch_num: 122 val_rmse: 1.022
# Still best_val_rmse: 0.6614 (from epoch 0)
#
# 16 steps took 11.7 seconds
# Epoch: 2 batch_num: 138 val_rmse: 1.023
# Still best_val_rmse: 0.6614 (from epoch 0)
#
# 16 steps took 11.7 seconds
# Epoch: 2 batch_num: 154 val_rmse: 1.022
# Still best_val_rmse: 0.6614 (from epoch 0)
#
# 16 steps took 11.8 seconds
# Epoch: 2 batch_num: 170 val_rmse: 1.024
# Still best_val_rmse: 0.6614 (from epoch 0)
#
# 16 steps took 11.7 seconds
# Epoch: 2 batch_num: 186 val_rmse: 1.023
# Still best_val_rmse: 0.6614 (from epoch 0)
#
# 16 steps took 11.7 seconds
# Epoch: 2 batch_num: 202 val_rmse: 1.023
# Still best_val_rmse: 0.6614 (from epoch 0)
#
# 16 steps took 11.7 seconds
# Epoch: 2 batch_num: 218 val_rmse: 1.024
# Still best_val_rmse: 0.6614 (from epoch 0)
#
# 16 steps took 11.7 seconds
# Epoch: 2 batch_num: 234 val_rmse: 1.024
# Still best_val_rmse: 0.6614 (from epoch 0)
#
# 16 steps took 11.7 seconds
# Epoch: 2 batch_num: 250 val_rmse: 1.024
# Still best_val_rmse: 0.6614 (from epoch 0)
#
# 16 steps took 11.7 seconds
# Epoch: 2 batch_num: 266 val_rmse: 1.024
# Still best_val_rmse: 0.6614 (from epoch 0)
#
# 16 steps took 11.8 seconds
# Epoch: 2 batch_num: 282 val_rmse: 1.024
# Still best_val_rmse: 0.6614 (from epoch 0)
#
# Performance estimates:
# [0.49805953176645995, 0.4736856332245972, 0.47809673197663416, 0.661411315004553]
# Mean: 0.5278133029930611
#
# Fold 5/5
# Some weights of RobertaModel were not initialized from the model checkpoint at /content/drive/MyDrive/CommonLit/input/commonlitreadabilityprize/roberta-large-mlm/clrp_roberta_large and are newly initialized: ['roberta.pooler.dense.weight', 'roberta.pooler.dense.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 16 steps took 12.6 seconds
# Epoch: 0 batch_num: 16 val_rmse: 0.947
# New best_val_rmse: 0.947
#
# 16 steps took 11.8 seconds
# Epoch: 0 batch_num: 32 val_rmse: 0.7881
# New best_val_rmse: 0.7881
#
# 16 steps took 11.8 seconds
# Epoch: 0 batch_num: 48 val_rmse: 0.6858
# New best_val_rmse: 0.6858
#
# 16 steps took 11.7 seconds
# Epoch: 0 batch_num: 64 val_rmse: 0.7439
# Still best_val_rmse: 0.6858 (from epoch 0)
#
# 16 steps took 11.7 seconds
# Epoch: 0 batch_num: 80 val_rmse: 0.8122
# Still best_val_rmse: 0.6858 (from epoch 0)
#
# 16 steps took 11.7 seconds
# Epoch: 0 batch_num: 96 val_rmse: 0.6663
# New best_val_rmse: 0.6663
#
# 16 steps took 11.8 seconds
# Epoch: 0 batch_num: 112 val_rmse: 0.9119
# Still best_val_rmse: 0.6663 (from epoch 0)
#
# 16 steps took 11.7 seconds
# Epoch: 0 batch_num: 128 val_rmse: 0.6024
# New best_val_rmse: 0.6024
#
# 16 steps took 11.8 seconds
# Epoch: 0 batch_num: 144 val_rmse: 0.633
# Still best_val_rmse: 0.6024 (from epoch 0)
#
# 16 steps took 11.8 seconds
# Epoch: 0 batch_num: 160 val_rmse: 0.6063
# Still best_val_rmse: 0.6024 (from epoch 0)
#
# 16 steps took 11.7 seconds
# Epoch: 0 batch_num: 176 val_rmse: 0.5858
# New best_val_rmse: 0.5858
#
# 16 steps took 11.8 seconds
# Epoch: 0 batch_num: 192 val_rmse: 0.5602
# New best_val_rmse: 0.5602
#
# 16 steps took 11.8 seconds
# Epoch: 0 batch_num: 208 val_rmse: 0.7758
# Still best_val_rmse: 0.5602 (from epoch 0)
#
# 16 steps took 11.7 seconds
# Epoch: 0 batch_num: 224 val_rmse: 0.5993
# Still best_val_rmse: 0.5602 (from epoch 0)
#
# 16 steps took 11.7 seconds
# Epoch: 0 batch_num: 240 val_rmse: 0.5927
# Still best_val_rmse: 0.5602 (from epoch 0)
#
# 16 steps took 11.7 seconds
# Epoch: 0 batch_num: 256 val_rmse: 0.5699
# Still best_val_rmse: 0.5602 (from epoch 0)
#
# 16 steps took 11.7 seconds
# Epoch: 0 batch_num: 272 val_rmse: 0.5782
# Still best_val_rmse: 0.5602 (from epoch 0)
#
# 16 steps took 11.9 seconds
# Epoch: 1 batch_num: 5 val_rmse: 0.8169
# Still best_val_rmse: 0.5602 (from epoch 0)
#
# 16 steps took 11.7 seconds
# Epoch: 1 batch_num: 21 val_rmse: 0.6977
# Still best_val_rmse: 0.5602 (from epoch 0)
#
# 16 steps took 11.7 seconds
# Epoch: 1 batch_num: 37 val_rmse: 0.6199
# Still best_val_rmse: 0.5602 (from epoch 0)
#
# 16 steps took 11.7 seconds
# Epoch: 1 batch_num: 53 val_rmse: 0.7366
# Still best_val_rmse: 0.5602 (from epoch 0)
#
# 16 steps took 11.7 seconds
# Epoch: 1 batch_num: 69 val_rmse: 0.5846
# Still best_val_rmse: 0.5602 (from epoch 0)
#
# 16 steps took 11.7 seconds
# Epoch: 1 batch_num: 85 val_rmse: 0.5873
# Still best_val_rmse: 0.5602 (from epoch 0)
#
# 16 steps took 11.7 seconds
# Epoch: 1 batch_num: 101 val_rmse: 0.6429
# Still best_val_rmse: 0.5602 (from epoch 0)
#
# 16 steps took 11.8 seconds
# Epoch: 1 batch_num: 117 val_rmse: 0.7606
# Still best_val_rmse: 0.5602 (from epoch 0)
#
# 16 steps took 11.7 seconds
# Epoch: 1 batch_num: 133 val_rmse: 0.6685
# Still best_val_rmse: 0.5602 (from epoch 0)
#
# 16 steps took 11.8 seconds
# Epoch: 1 batch_num: 149 val_rmse: 0.5596
# New best_val_rmse: 0.5596
#
# 16 steps took 11.8 seconds
# Epoch: 1 batch_num: 165 val_rmse: 0.6153
# Still best_val_rmse: 0.5596 (from epoch 1)
#
# 16 steps took 11.8 seconds
# Epoch: 1 batch_num: 181 val_rmse: 0.5316
# New best_val_rmse: 0.5316
#
# 16 steps took 11.8 seconds
# Epoch: 1 batch_num: 197 val_rmse: 0.59
# Still best_val_rmse: 0.5316 (from epoch 1)
#
# 16 steps took 11.8 seconds
# Epoch: 1 batch_num: 213 val_rmse: 0.5571
# Still best_val_rmse: 0.5316 (from epoch 1)
#
# 16 steps took 11.8 seconds
# Epoch: 1 batch_num: 229 val_rmse: 0.5446
# Still best_val_rmse: 0.5316 (from epoch 1)
#
# 16 steps took 11.7 seconds
# Epoch: 1 batch_num: 245 val_rmse: 0.5292
# New best_val_rmse: 0.5292
#
# 16 steps took 11.8 seconds
# Epoch: 1 batch_num: 261 val_rmse: 0.5231
# New best_val_rmse: 0.5231
#
# 16 steps took 11.8 seconds
# Epoch: 1 batch_num: 277 val_rmse: 0.5418
# Still best_val_rmse: 0.5231 (from epoch 1)
#
# 16 steps took 12.0 seconds
# Epoch: 2 batch_num: 10 val_rmse: 0.5249
# Still best_val_rmse: 0.5231 (from epoch 1)
#
# 16 steps took 11.7 seconds
# Epoch: 2 batch_num: 26 val_rmse: 0.5249
# Still best_val_rmse: 0.5231 (from epoch 1)
#
# 16 steps took 11.7 seconds
# Epoch: 2 batch_num: 42 val_rmse: 0.5144
# New best_val_rmse: 0.5144
#
# 16 steps took 11.8 seconds
# Epoch: 2 batch_num: 58 val_rmse: 0.5083
# New best_val_rmse: 0.5083
#
# 16 steps took 11.7 seconds
# Epoch: 2 batch_num: 74 val_rmse: 0.5098
# Still best_val_rmse: 0.5083 (from epoch 2)
#
# 16 steps took 11.8 seconds
# Epoch: 2 batch_num: 90 val_rmse: 0.5098
# Still best_val_rmse: 0.5083 (from epoch 2)
#
# 16 steps took 11.7 seconds
# Epoch: 2 batch_num: 106 val_rmse: 0.5359
# Still best_val_rmse: 0.5083 (from epoch 2)
#
# 16 steps took 11.7 seconds
# Epoch: 2 batch_num: 122 val_rmse: 0.515
# Still best_val_rmse: 0.5083 (from epoch 2)
#
# 16 steps took 11.7 seconds
# Epoch: 2 batch_num: 138 val_rmse: 0.5039
# New best_val_rmse: 0.5039
#
# 16 steps took 11.8 seconds
# Epoch: 2 batch_num: 154 val_rmse: 0.518
# Still best_val_rmse: 0.5039 (from epoch 2)
#
# 16 steps took 11.8 seconds
# Epoch: 2 batch_num: 170 val_rmse: 0.5089
# Still best_val_rmse: 0.5039 (from epoch 2)
#
# 16 steps took 11.7 seconds
# Epoch: 2 batch_num: 186 val_rmse: 0.5021
# New best_val_rmse: 0.5021
#
# 16 steps took 11.8 seconds
# Epoch: 2 batch_num: 202 val_rmse: 0.5164
# Still best_val_rmse: 0.5021 (from epoch 2)
#
# 16 steps took 11.7 seconds
# Epoch: 2 batch_num: 218 val_rmse: 0.5156
# Still best_val_rmse: 0.5021 (from epoch 2)
#
# 16 steps took 11.7 seconds
# Epoch: 2 batch_num: 234 val_rmse: 0.5101
# Still best_val_rmse: 0.5021 (from epoch 2)
#
# 16 steps took 11.7 seconds
# Epoch: 2 batch_num: 250 val_rmse: 0.508
# Still best_val_rmse: 0.5021 (from epoch 2)
#
# 16 steps took 11.7 seconds
# Epoch: 2 batch_num: 266 val_rmse: 0.5095
# Still best_val_rmse: 0.5021 (from epoch 2)
#
# 16 steps took 11.7 seconds
# Epoch: 2 batch_num: 282 val_rmse: 0.5093
# Still best_val_rmse: 0.5021 (from epoch 2)
#
# Performance estimates:
# [0.49805953176645995, 0.4736856332245972, 0.47809673197663416, 0.661411315004553, 0.5020951587008314]
# Mean: 0.5226696741346151

# %% [markdown]
# # Inference

# %%
test_dataset = LitDataset(test_df, inference_only=True)

# %%
all_predictions = np.zeros((len(list_val_rmse), len(test_df)))

test_dataset = LitDataset(test_df, inference_only=True)
test_loader = DataLoader(test_dataset, batch_size=BATCH_SIZE,
                         drop_last=False, shuffle=False, num_workers=2)

for index in range(len(list_val_rmse)):            
    # model_path = f"/content/drive/MyDrive/CommonLit/output/roberta-large-meanpooling-pretrain/model_{index + 1}.pth"
    model_path = PATH + f"model_{fold + 1}.pth"
    print(f"\nUsing {model_path}")
                        
    model = LitModel()
    model.load_state_dict(torch.load(model_path))    
    model.to(DEVICE)
    
    all_predictions[index] = predict(model, test_loader)
    
    del model
    gc.collect()
# Out:
# Using /content/drive/MyDrive/CommonLit/output/roberta-large-meanpooling-pretrain/model_5.pth
# Some weights of RobertaModel were not initialized from the model checkpoint at /content/drive/MyDrive/CommonLit/input/commonlitreadabilityprize/roberta-large-mlm/clrp_roberta_large and are newly initialized: ['roberta.pooler.dense.weight', 'roberta.pooler.dense.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Using /content/drive/MyDrive/CommonLit/output/roberta-large-meanpooling-pretrain/model_5.pth
# Some weights of RobertaModel were not initialized from the model checkpoint at /content/drive/MyDrive/CommonLit/input/commonlitreadabilityprize/roberta-large-mlm/clrp_roberta_large and are newly initialized: ['roberta.pooler.dense.weight', 'roberta.pooler.dense.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Using /content/drive/MyDrive/CommonLit/output/roberta-large-meanpooling-pretrain/model_5.pth
# Some weights of RobertaModel were not initialized from the model checkpoint at /content/drive/MyDrive/CommonLit/input/commonlitreadabilityprize/roberta-large-mlm/clrp_roberta_large and are newly initialized: ['roberta.pooler.dense.weight', 'roberta.pooler.dense.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Using /content/drive/MyDrive/CommonLit/output/roberta-large-meanpooling-pretrain/model_5.pth
# Some weights of RobertaModel were not initialized from the model checkpoint at /content/drive/MyDrive/CommonLit/input/commonlitreadabilityprize/roberta-large-mlm/clrp_roberta_large and are newly initialized: ['roberta.pooler.dense.weight', 'roberta.pooler.dense.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Using /content/drive/MyDrive/CommonLit/output/roberta-large-meanpooling-pretrain/model_5.pth
# Some weights of RobertaModel were not initialized from the model checkpoint at /content/drive/MyDrive/CommonLit/input/commonlitreadabilityprize/roberta-large-mlm/clrp_roberta_large and are newly initialized: ['roberta.pooler.dense.weight', 'roberta.pooler.dense.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
predictions = all_predictions.mean(axis=0)
submission_df.target = predictions
print(submission_df)
#submission_df.to_csv("submission.csv", index=False)
# Out:
#           id    target
# 0  c0f722661 -0.405769
# 1  f0953f0a5 -0.533787
# 2  0df072751 -0.492256
# 3  04caf4e0c -2.521435
# 4  0e63f8bea -1.969021
# 5  12537fe78 -1.162841
# 6  965e592c0  0.539834

# %% [markdown]
# ## Upload model

# %%
# !kaggle datasets init -p /content/drive/MyDrive/CommonLit/input


# !pip install -q kaggle
# !mkdir /root/.kaggle
# !cp /content/drive/MyDrive/Colab\ Notebooks/kaggle.json /root/.kaggle/
# Out:
# mkdir: cannot create directory ‘/root/.kaggle’: File exists

# %%
# !mkdir -p ./output/
# !cp -f ./model* ./output/
# !cp -f /content/drive/MyDrive/CommonLit/output/roberta-large-meanpooling-pretrain/model*
# !echo done
#CHANGEME
# !cp -f /content/drive/MyDrive/CommonLit/input/commonlitreadabilityprize/dataset-metadata.json /content/output/dataset-metadata.json
# !echo done
# !sed -i -e "s/roberta-base/roberta-large-`TZ=JST-9 date +"%Y%m%d%H%M%S"`/" ./output/dataset-metadata.json
# !sed -i -e "s/Roberta-base/Roberta-large-`TZ=JST-9 date +"%m%d%H%M%S"`/" ./output/dataset-metadata.json
# !echo done
# !cat ./output/dataset-metadata.json
# !kaggle datasets create -p /content/output/


# !mkdir -p ./output/
# !cp -f ./model* ./output/
# #CHANGEME
# !cp -f ./drive/MyDrive/kaggle/commonlit/pretrained-roberta-base/dataset-metadata.json ./output/dataset-metadata.json
# !sed -i -e "s/roberta-base/roberta-large-`TZ=JST-9 date +"%Y%m%d%H%M%S"`/" ./output/dataset-metadata.json
# !sed -i -e "s/Roberta-base/Roberta-large-`TZ=JST-9 date +"%m%d%H%M%S"`/" ./output/dataset-metadata.json
# !kaggle datasets create -p ./output/
# Out:
# cp: target '/content/drive/MyDrive/CommonLit/output/roberta-large-meanpooling-pretrain/model_5.pth' is not a directory
# done
# done
# done
# {
#   "licenses": [
#     {
#       "name": "CC0-1.0"
#     }
#   ],
#   "id": "takeshikobayashi/roberta-large-maunish-meanpooling_pretrain_step200",
#   "title": "roberta-large-maunish-meanpooling_pretrain_step200"
# }400 - Bad Request

# %%
# !cat ./output/dataset-metadata.json
# Out:
# {
#   "licenses": [
#     {
#       "name": "CC0-1.0"
#     }
#   ],
#   "id": "iamnishipy/roberta-large-20210719013114",
#   "title": "Roberta-large-0719013114"
# }
